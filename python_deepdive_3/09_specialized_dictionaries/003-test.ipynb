# %% [markdown]
# ### defaultdict

# %%
from collections import defaultdict

# %%
d = {}
d['a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 d = {}
# ----> 2 d['a']
#
# KeyError: 'a'

# %%
result = d.get('a')

# %%
type(result)
# Out:
# NoneType

# %%
result = d.get('a', 100)

# %%
result
# Out:
# 100

# %%
d
# Out:
# {}
