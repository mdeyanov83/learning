# %% [markdown]
# ### UserDict

# %%
from numbers import Real

class IntDict:
    def __init__(self):
        self._d = {}

    def __setitem__(self, key, value):
        if not isinstance(value, Real):
            raise ValueError('Value must be a real number')
        self._d[key] = value

    def __getitem__(self, key):
        return int(self._d[key])

# %%
d = IntDict()

# %%
d['a'] = 10.5

# %%
d['a']
# Out:
# 10

# %%
d['a'] = 3 + 2j
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 d['a'] = 3 + 2j
#
# Cell In[1], line 9, in IntDict.__setitem__(self, key, value)
#       7 def __setitem__(self, key, value):
#       8     if not isinstance(value, Real):
# ----> 9         raise ValueError('Value must be a real number')
#      10     self._d[key] = value
#
# ValueError: Value must be a real number

# %%
d['x']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 d['x']
#
# Cell In[1], line 13, in IntDict.__getitem__(self, key)
#      12 def __getitem__(self, key):
# ---> 13     return int(self._d[key])
#
# KeyError: 'x'

# %%
d.get('x')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 d.get('x')
#
# AttributeError: 'IntDict' object has no attribute 'get'

# %%
class IntDict(dict):
    def __setitem__(self, key, value):
        if not isinstance(value, Real):
            raise ValueError('Value must be a real number')
        super().__setitem__(key, value)

    def __getitem__(self, key):
        return int(super().__getitem__(key))

# %%
d = IntDict()

# %%
d['a'] = 10.5

# %%
d['a']
# Out:
# 10

# %%
d['b'] = 'python'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 d['b'] = 'python'
#
# Cell In[9], line 4, in IntDict.__setitem__(self, key, value)
#       2 def __setitem__(self, key, value):
#       3     if not isinstance(value, Real):
# ----> 4         raise ValueError('Value must be a real number')
#       5     super().__setitem__(key, value)
#
# ValueError: Value must be a real number

# %%
d.keys()
# Out:
# dict_keys(['a'])

# %%
d['b'] = 100.5

# %%
d.keys()
# Out:
# dict_keys(['a', 'b'])

# %%
d.items()
# Out:
# dict_items([('a', 10.5), ('b', 100.5)])

# %%
d.get('a')
# Out:
# 10.5

# %%
d.get('x', 'None')
# Out:
# 'None'

# %%
d['a'], d['b']
# Out:
# (10, 100)

# %%
d
# Out:
# {'a': 10, 'b': 100}

# %%
d1 = {}
d1.update(d)

# %%
d1
# Out:
# {'a': 10.5, 'b': 100.5}

# %%
type(d)
# Out:
# __main__.IntDict

# %%
d.update({'c': 100.5})

# %%
d.update({'d': 'python'})

# %%
dict(d)
# Out:
# {'a': 10.5, 'b': 100.5, 'c': 100.5, 'd': 'python'}

# %%
d['d']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 d['d']
#
# Cell In[9], line 8, in IntDict.__getitem__(self, key)
#       7 def __getitem__(self, key):
# ----> 8     return int(super().__getitem__(key))
#
# ValueError: invalid literal for int() with base 10: 'python'
