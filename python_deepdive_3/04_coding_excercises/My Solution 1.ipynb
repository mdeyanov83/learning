# %% [markdown]
# ### Solution 1

# %%
composers = {'Johann': 65, 'Ludwig': 56, 'Frederic': 39, 'Wolfgang': 35}

# %%
def sort_dict(d):
    return {k: v for k, v in sorted(d, reverse=True)}

# %%
print(sort_dict(composers))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(sort_dict(composers))
#
# Cell In[5], line 2, in sort_dict(d)
#       1 def sort_dict(d):
# ----> 2     return {k: v for (k, v) in sorted(d, reverse=True)}
#
# ValueError: too many values to unpack (expected 2)
