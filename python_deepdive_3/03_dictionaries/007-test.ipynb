# %% [markdown]
# ### Views: keys, values and items

# %%
s1 = {1, 2, 3}
s2 = {2, 3, 4}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4}

# %%
s1 & s2
# Out:
# {2, 3}

# %%
s1 - s2
# Out:
# {1}

# %%
s2 - s1
# Out:
# {4}
