# %% [markdown]
# ### Common Operations

# %%
d = dict(zip('abc', range(1, 4)))

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
len(d)
# Out:
# 3

# %%
d['a']
# Out:
# 1

# %%
d['python']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 d['python']
#
# KeyError: 'python'

# %%
d.get('a')
# Out:
# 1

# %%
result = d.get('python')

# %%
type(result)
# Out:
# NoneType

# %%
d.get('z', 'N/A')
# Out:
# 'N/A'

# %%
d.get('a', 'N/A')
# Out:
# 1
