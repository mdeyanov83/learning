# %% [markdown]
# ### Custom Classes and Hashing

# %%
t1 = (1, 2, 3)

# %%
t2 = (1, 2, 3)

# %%
id(t1), id(t1)
# Out:
# (139677657104832, 139677657104832)

# %%
t1 == t2
# Out:
# True

# %%
t1 is t2
# Out:
# False

# %%
hash(t1), hash(t2)
# Out:
# (529344067295497451, 529344067295497451)

# %%
d = {t1: 100}

# %%
d[t1]
# Out:
# 100

# %%
d[t2]
# Out:
# 100

# %%
d[(1, 2, 3)]
# Out:
# 100

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        return f'Person(name={self.name}, age={self.age}'

# %%
p1 = Person('Jonh', 78)
p2 = Person('John', 78)

# %%
p1 is p2
# Out:
# False

# %%
p1 == p2
# Out:
# False

# %%
hash(p1), hash(p2)
# Out:
# (8729822908201, 8729853009024)

# %%
p1 = Person('John', 78)
p2 = Person('Eric', 75)
persons = {p1: 'John object', p2: 'Eric object'}

# %%
for k in persons.keys():
    print(k)
# Out:
# Person(name=John, age=78
# Person(name=Eric, age=75

# %%
persons[Person('John', 78)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 persons[Person('John', 78)]
#
# KeyError: Person(name=John, age=78

# %%
persons[p1]
# Out:
# 'John object'

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        return f'Person(name={self.name}, age={self.age}'

    def __eq__(self, other):
        if isinstance(other, Person):
            return self.name == other.name and self.age == self.age
        else:
            return False

# %%
p1 = Person('John', 78)
p2 = Person('John', 78)

# %%
p1 is p2
# Out:
# False

# %%
p1 == p2
# Out:
# True

# %%
persons = {p1: 'John p1'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 persons = {p1: 'John p1'}
#
# TypeError: unhashable type: 'Person'

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        return f'Person(name={self.name}, age={self.age}'

    def __eq__(self, other):
        if isinstance(other, Person):
            return self.name == other.name and self.age == self.age
        else:
            return False

    def __hash__(self):
        return 100

# %%
p1 = Person('John', 78)

# %%
hash(p1)
# Out:
# 100

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        return f'Person(name={self.name}, age={self.age}'

    __hash__ = None

# %%
p = Person('Eric', 75)

# %%
hash(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 hash(p)
#
# TypeError: unhashable type: 'Person'

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        return f'Person(name={self.name}, age={self.age}'

    def __eq__(self, other):
        if isinstance(other, Person):
            return self.name == other.name and self.age == self.age
        else:
            return False

    def __hash__(self):
        return hash((self.name, self.age))

# %%
p1 = Person('John', 78)

# %%
hash(p1)
# Out:
# -4895934635983230034

# %%
p1 = Person('John', 78)
p2 = Person('Eric', 75)
persons = {p1: 'John object', p2: 'Eric object'}

# %%
persons[p1]
# Out:
# 'John object'

# %%
persons[Person('John', 78)]
# Out:
# 'John object'

# %%
p3 = Person('John', 78)

# %%
p1 is p3
# Out:
# False

# %%
p1 == p3
# Out:
# True

# %%
hash(p1) == hash(p3)
# Out:
# True

# %%
persons[p1] is persons[p3]
# Out:
# True
