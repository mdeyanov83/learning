# %% [markdown]
# ### Creating Python Dictionaries

# %%
a = {'k1': 100, 'k2': 200}

# %%
type(a)
# Out:
# dict

# %%
a
# Out:
# {'k1': 100, 'k2': 200}

# %%
print(a)
# Out:
# {'k1': 100, 'k2': 200}

# %%
hash((1, 2, 3))
# Out:
# 529344067295497451

# %%
hash((1, 2, 3))
# Out:
# 529344067295497451

# %%
d = {(1, 2, 3): 'this is a tuple'}

# %%
d
# Out:
# {(1, 2, 3): 'this is a tuple'}

# %%
d[(1, 2, 3)]
# Out:
# 'this is a tuple'

# %%
t1 = (1, 2, 3)

# %%
t2 = (1, 2, 3)

# %%
t1 == t2
# Out:
# True

# %%
hash(t1) == hash(t2)
# Out:
# True

# %%
t1 is t2
# Out:
# False

# %%
d[t1]
# Out:
# 'this is a tuple'

# %%
d[t2]
# Out:
# 'this is a tuple'
