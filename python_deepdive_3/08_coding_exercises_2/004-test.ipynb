# %% [markdown]
# ### Exercise 3 - Solution

# %% [markdown]
# Here we want to use Marshmallow to do the serialization and deserialization that we did in Exercises 1 and 2.

# %%
class Stock:
    def __init__(self, symbol, date, open_, high, low, close, volume):
        self.symbol = symbol
        self.date = date
        self.open = open_
        self.high = high
        self.low = low
        self.close = close
        self.volume = volume

class Trade:
    def __init__(self, symbol, timestamp, order, price, volume, commission):
        self.symbol = symbol
        self.timestamp = timestamp
        self.order = order
        self.price = price
        self.commission = commission
        self.volume = volume

# %%
from datetime import date, datetime
from decimal import Decimal

activity = {
    "quotes": [
        Stock('TSLA', date(2018, 11, 22),
              Decimal('338.19'), Decimal('338.64'), Decimal('337.60'), Decimal('338.19'), 365_607),
        Stock('AAPL', date(2018, 11, 22),
              Decimal('176.66'), Decimal('177.25'), Decimal('176.64'), Decimal('176.78'), 3_699_184),
        Stock('MSFT', date(2018, 11, 22),
              Decimal('103.25'), Decimal('103.48'), Decimal('103.07'), Decimal('103.11'), 4_493_689)
    ],

    "trades": [
        Trade('TSLA', datetime(2018, 11, 22, 10, 5, 12), 'buy', Decimal('338.25'), 100, Decimal('9.99')),
        Trade('AAPL', datetime(2018, 11, 22, 10, 30, 5), 'sell', Decimal('177.01'), 20, Decimal('9.99'))
    ]
}

# %%
from marshmallow import Schema, fields

# %%
class StockSchema(Schema):
    symbol = fields.Str()
    date = fields.Date()
    open = fields.Decimal()
    high = fields.Decimal()
    low = fields.Decimal()
    close = fields.Decimal()
    volume = fields.Int()

# %%
StockSchema().dump(Stock('TSLA', date(2018, 11, 22),
              Decimal('338.19'), Decimal('338.64'), Decimal('337.60'), Decimal('338.19'), 365_607))
# Out:
# {'symbol': 'TSLA',
#  'date': '2018-11-22',
#  'open': Decimal('338.19'),
#  'high': Decimal('338.64'),
#  'low': Decimal('337.60'),
#  'close': Decimal('338.19'),
#  'volume': 365607}

# %%
StockSchema().dumps(Stock('TSLA', date(2018, 11, 22),
              Decimal('338.19'), Decimal('338.64'), Decimal('337.60'), Decimal('338.19'), 365_607))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 StockSchema().dumps(Stock('TSLA', date(2018, 11, 22),
#       2               Decimal('338.19'), Decimal('338.64'), Decimal('337.60'), Decimal('338.19'), 365_607))
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:590, in Schema.dumps(self, obj, many, *args, **kwargs)
#     577 """Same as :meth:`dump`, except return a JSON-encoded string.
#     578
#     579 :param obj: The object to serialize.
#    (...)    587     if ``obj`` is invalid.
#     588 """
#     589 serialized = self.dump(obj, many=many)
# --> 590 return self.opts.render_module.dumps(serialized, *args, **kwargs)
#
# File /usr/lib/python3.12/json/__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File /usr/lib/python3.12/json/encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File /usr/lib/python3.12/json/encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File /usr/lib/python3.12/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type Decimal is not JSON serializable

# %%
class StockSchema(Schema):
    symbol = fields.Str()
    date = fields.Date()
    open = fields.Decimal(as_string=True)
    high = fields.Decimal(as_string=True)
    low = fields.Decimal(as_string=True)
    close = fields.Decimal(as_string=True)
    volume = fields.Int()

# %%
StockSchema().dump(Stock('TSLA', date(2018, 11, 22),
              Decimal('338.19'), Decimal('338.64'), Decimal('337.60'), Decimal('338.19'), 365_607))
# Out:
# {'symbol': 'TSLA',
#  'date': '2018-11-22',
#  'open': '338.19',
#  'high': '338.64',
#  'low': '337.60',
#  'close': '338.19',
#  'volume': 365607}

# %%
StockSchema().dumps(Stock('TSLA', date(2018, 11, 22),
              Decimal('338.19'), Decimal('338.64'), Decimal('337.60'), Decimal('338.19'), 365_607))
# Out:
# '{"symbol": "TSLA", "date": "2018-11-22", "open": "338.19", "high": "338.64", "low": "337.60", "close": "338.19", "volume": 365607}'

# %%
class TradeSchema(Schema):
    symbol = fields.Str()
    timestamp = fields.DateTime()
    order = fields.Str()
    price = fields.Decimal(as_string=True)
    commission = fields.Decimal(as_string=True)
    volume = fields.Integer()

# %%
TradeSchema().dumps(Trade('AAPL', datetime(2018, 11, 22, 10, 30, 5), 'sell', Decimal('177.01'), 20, Decimal('9.99')))
# Out:
# '{"symbol": "AAPL", "timestamp": "2018-11-22T10:30:05", "order": "sell", "price": "177.01", "commission": "9.99", "volume": 20}'

# %%
class ActivitySchema(Schema):
    quotes = fields.Nested(StockSchema, many=True)
    trades = fields.Nested(TradeSchema, many=True)

# %%
result = ActivitySchema().dumps(activity, indent=2)

# %%
type(result)
# Out:
# str

# %%
print(result)
# Out:
# {
#   "quotes": [
#     {
#       "symbol": "TSLA",
#       "date": "2018-11-22",
#       "open": "338.19",
#       "high": "338.64",
#       "low": "337.60",
#       "close": "338.19",
#       "volume": 365607
#     },
#     {
#       "symbol": "AAPL",
#       "date": "2018-11-22",
#       "open": "176.66",
#       "high": "177.25",
#       "low": "176.64",
#       "close": "176.78",
#       "volume": 3699184
#     },
#     {
#       "symbol": "MSFT",
#       "date": "2018-11-22",
#       "open": "103.25",
#       "high": "103.48",
#       "low": "103.07",
#       "close": "103.11",
#       "volume": 4493689
#     }
#   ],
#   "trades": [
#     {
#       "symbol": "TSLA",
#       "timestamp": "2018-11-22T10:05:12",
#       "order": "buy",
#       "price": "338.25",
#       "commission": "9.99",
#       "volume": 100
#     },
#     {
#       "symbol": "AAPL",
#       "timestamp": "2018-11-22T10:30:05",
#       "order": "sell",
#       "price": "177.01",
#       "commission": "9.99",
#       "volume": 20
#     }
#   ]
# }

# %%
activity_deser = ActivitySchema().loads(result)

# %%
type(activity_deser)
# Out:
# dict

# %%
from pprint import pprint

pprint(activity_deser)
# Out:
# {'quotes': [{'close': Decimal('338.19'),
#              'date': datetime.date(2018, 11, 22),
#              'high': Decimal('338.64'),
#              'low': Decimal('337.60'),
#              'open': Decimal('338.19'),
#              'symbol': 'TSLA',
#              'volume': 365607},
#             {'close': Decimal('176.78'),
#              'date': datetime.date(2018, 11, 22),
#              'high': Decimal('177.25'),
#              'low': Decimal('176.64'),
#              'open': Decimal('176.66'),
#              'symbol': 'AAPL',
#              'volume': 3699184},
#             {'close': Decimal('103.11'),
#              'date': datetime.date(2018, 11, 22),
#              'high': Decimal('103.48'),
#              'low': Decimal('103.07'),
#              'open': Decimal('103.25'),
#              'symbol': 'MSFT',
#              'volume': 4493689}],
#  'trades': [{'commission': Decimal('9.99'),
#              'order': 'buy',
#              'price': Decimal('338.25'),
#              'symbol': 'TSLA',
#              'timestamp': datetime.datetime(2018, 11, 22, 10, 5, 12),
#              'volume': 100},
#             {'commission': Decimal('9.99'),
#              'order': 'sell',
#              'price': Decimal('177.01'),
#              'symbol': 'AAPL',
#              'timestamp': datetime.datetime(2018, 11, 22, 10, 30, 5),
#              'volume': 20}]}

# %%
from marshmallow import post_load

class TradeSchema(Schema):
    symbol = fields.Str()
    timestamp = fields.DateTime()
    order = fields.Str()
    price = fields.Decimal(as_string=True)
    commission = fields.Decimal(as_string=True)
    volume = fields.Integer()

    @post_load
    def make_trade(self, data, **kwargs):
        return Trade(**data)

class StockSchema(Schema):
    symbol = fields.Str()
    date = fields.Date()
    open = fields.Decimal(as_string=True)
    high = fields.Decimal(as_string=True)
    low = fields.Decimal(as_string=True)
    close = fields.Decimal(as_string=True)
    volume = fields.Int()

    @post_load
    def make_stock(self, data, **kwargs):
        return Stock(**data)


class ActivitySchema(Schema):
    quotes = fields.Nested(StockSchema, many=True)
    trades = fields.Nested(TradeSchema, many=True)

# %%
result = ActivitySchema().dumps(activity, indent=2)

# %%
print(result)
# Out:
# {
#   "quotes": [
#     {
#       "symbol": "TSLA",
#       "date": "2018-11-22",
#       "open": "338.19",
#       "high": "338.64",
#       "low": "337.60",
#       "close": "338.19",
#       "volume": 365607
#     },
#     {
#       "symbol": "AAPL",
#       "date": "2018-11-22",
#       "open": "176.66",
#       "high": "177.25",
#       "low": "176.64",
#       "close": "176.78",
#       "volume": 3699184
#     },
#     {
#       "symbol": "MSFT",
#       "date": "2018-11-22",
#       "open": "103.25",
#       "high": "103.48",
#       "low": "103.07",
#       "close": "103.11",
#       "volume": 4493689
#     }
#   ],
#   "trades": [
#     {
#       "symbol": "TSLA",
#       "timestamp": "2018-11-22T10:05:12",
#       "order": "buy",
#       "price": "338.25",
#       "commission": "9.99",
#       "volume": 100
#     },
#     {
#       "symbol": "AAPL",
#       "timestamp": "2018-11-22T10:30:05",
#       "order": "sell",
#       "price": "177.01",
#       "commission": "9.99",
#       "volume": 20
#     }
#   ]
# }

# %%
activity_deser = ActivitySchema().loads(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 activity_deser = ActivitySchema().loads(result)
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:767, in Schema.loads(self, s, many, partial, unknown, **kwargs)
#     744 """Same as :meth:`load`, except it uses `marshmallow.Schema.Meta.render_module` to deserialize
#     745 the passed string before passing data to :meth:`load`.
#     746
#    (...)    764     Rename ``json_module`` parameter to ``s``.
#     765 """
#     766 data = self.opts.render_module.loads(s, **kwargs)
# --> 767 return self.load(data, many=many, partial=partial, unknown=unknown)
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:730, in Schema.load(self, data, many, partial, unknown)
#     703 def load(
#     704     self,
#     705     data: Mapping[str, typing.Any] | Sequence[Mapping[str, typing.Any]],
#    (...)    709     unknown: types.UnknownOption | None = None,
#     710 ):
#     711     """Deserialize a data structure to an object defined by this Schema's fields.
#     712
#     713     :param data: The data to deserialize.
#    (...)    728         if invalid data are passed.
#     729     """
# --> 730     return self._do_load(
#     731         data, many=many, partial=partial, unknown=unknown, postprocess=True
#     732     )
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:887, in Schema._do_load(self, data, many, partial, unknown, postprocess)
#     884     processed_data = data
#     885 if not errors:
#     886     # Deserialize data
# --> 887     result = self._deserialize(
#     888         processed_data,
#     889         error_store=error_store,
#     890         many=many,
#     891         partial=partial,
#     892         unknown=unknown,
#     893     )
#     894     # Run field-level validation
#     895     self._invoke_field_validators(
#     896         error_store=error_store, data=result, many=many
#     897     )
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:676, in Schema._deserialize(self, data, error_store, many, partial, unknown, index)
#     666 def getter(
#     667     val, field_obj=field_obj, field_name=field_name, d_kwargs=d_kwargs
#     668 ):
#     669     return field_obj.deserialize(
#     670         val,
#     671         field_name,
#     672         data,
#     673         **d_kwargs,
#     674     )
# --> 676 value = self._call_and_store(
#     677     getter_func=getter,
#     678     data=raw_value,
#     679     field_name=field_name,
#     680     error_store=error_store,
#     681     index=index,
#     682 )
#     683 if value is not missing:
#     684     key = field_obj.attribute or attr_name
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:517, in Schema._call_and_store(getter_func, data, field_name, error_store, index)
#     507 """Call ``getter_func`` with ``data`` as its argument, and store any `ValidationErrors`.
#     508
#     509 :param getter_func: Function for getting the serialized/deserialized
#    (...)    514     otherwise `None`.
#     515 """
#     516 try:
# --> 517     value = getter_func(data)
#     518 except ValidationError as error:
#     519     error_store.store_error(error.messages, field_name, index=index)
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:669, in Schema._deserialize.<locals>.getter(val, field_obj, field_name, d_kwargs)
#     666 def getter(
#     667     val, field_obj=field_obj, field_name=field_name, d_kwargs=d_kwargs
#     668 ):
# --> 669     return field_obj.deserialize(
#     670         val,
#     671         field_name,
#     672         data,
#     673         **d_kwargs,
#     674     )
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/fields.py:374, in Field.deserialize(self, value, attr, data, **kwargs)
#     372 if self.allow_none and value is None:
#     373     return None
# --> 374 output = self._deserialize(value, attr, data, **kwargs)
#     375 self._validate(output)
#     376 return output
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/fields.py:628, in Nested._deserialize(self, value, attr, data, partial, **kwargs)
#     619 """Same as :meth:`Field._deserialize` with additional ``partial`` argument.
#     620
#     621 :param partial: For nested schemas, the ``partial``
#    (...)    625     Add ``partial`` parameter.
#     626 """
#     627 self._test_collection(value)
# --> 628 return self._load(value, partial=partial)
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/fields.py:604, in Nested._load(self, value, partial)
#     598 def _load(
#     599     self,
#     600     value: typing.Any,
#     601     partial: bool | types.StrSequenceOrSet | None = None,  # noqa: FBT001
#     602 ):
#     603     try:
# --> 604         valid_data = self.schema.load(value, unknown=self.unknown, partial=partial)
#     605     except ValidationError as error:
#     606         raise ValidationError(
#     607             error.messages, valid_data=error.valid_data
#     608         ) from error
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:730, in Schema.load(self, data, many, partial, unknown)
#     703 def load(
#     704     self,
#     705     data: Mapping[str, typing.Any] | Sequence[Mapping[str, typing.Any]],
#    (...)    709     unknown: types.UnknownOption | None = None,
#     710 ):
#     711     """Deserialize a data structure to an object defined by this Schema's fields.
#     712
#     713     :param data: The data to deserialize.
#    (...)    728         if invalid data are passed.
#     729     """
# --> 730     return self._do_load(
#     731         data, many=many, partial=partial, unknown=unknown, postprocess=True
#     732     )
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:925, in Schema._do_load(self, data, many, partial, unknown, postprocess)
#     923 if not errors and postprocess and self._hooks[POST_LOAD]:
#     924     try:
# --> 925         result = self._invoke_load_processors(
#     926             POST_LOAD,
#     927             result,
#     928             many=many,
#     929             original_data=data,
#     930             partial=partial,
#     931             unknown=unknown,
#     932         )
#     933     except ValidationError as err:
#     934         errors = err.normalized_messages()
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:1110, in Schema._invoke_load_processors(self, tag, data, many, original_data, partial, unknown)
#    1089 def _invoke_load_processors(
#    1090     self,
#    1091     tag: str,
#    (...)   1099     # This has to invert the order of the dump processors, so run the pass_collection
#    1100     # processors first.
#    1101     data = self._invoke_processors(
#    1102         tag,
#    1103         pass_collection=True,
#    (...)   1108         unknown=unknown,
#    1109     )
# -> 1110     return self._invoke_processors(
#    1111         tag,
#    1112         pass_collection=False,
#    1113         data=data,
#    1114         many=many,
#    1115         original_data=original_data,
#    1116         partial=partial,
#    1117         unknown=unknown,
#    1118     )
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:1241, in Schema._invoke_processors(self, tag, pass_collection, data, many, original_data, **kwargs)
#    1236         data = [
#    1237             processor(item, original, many=many, **kwargs)
#    1238             for item, original in zip_longest(data, original_data)
#    1239         ]
#    1240     else:
# -> 1241         data = [processor(item, many=many, **kwargs) for item in data]
#    1242 elif pass_original:
#    1243     data = processor(data, original_data, many=many, **kwargs)
#
# Cell In[67], line 26, in StockSchema.make_stock(self, data, **kwargs)
#      24 @post_load
#      25 def make_stock(self, data, **kwargs):
# ---> 26     return Stock(**data)
#
# TypeError: Stock.__init__() got an unexpected keyword argument 'open'

# %%
pprint(activity_deser)
# Out:
# {'quotes': [{'close': Decimal('338.19'),
#              'date': datetime.date(2018, 11, 22),
#              'high': Decimal('338.64'),
#              'low': Decimal('337.60'),
#              'open': Decimal('338.19'),
#              'symbol': 'TSLA',
#              'volume': 365607},
#             {'close': Decimal('176.78'),
#              'date': datetime.date(2018, 11, 22),
#              'high': Decimal('177.25'),
#              'low': Decimal('176.64'),
#              'open': Decimal('176.66'),
#              'symbol': 'AAPL',
#              'volume': 3699184},
#             {'close': Decimal('103.11'),
#              'date': datetime.date(2018, 11, 22),
#              'high': Decimal('103.48'),
#              'low': Decimal('103.07'),
#              'open': Decimal('103.25'),
#              'symbol': 'MSFT',
#              'volume': 4493689}],
#  'trades': [<__main__.Trade object at 0x7f8fad4eef90>,
#             <__main__.Trade object at 0x7f8fad4ec200>]}
