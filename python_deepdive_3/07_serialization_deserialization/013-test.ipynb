# %% [markdown]
# ### Using JSONDecoder

# %%
import json

# %%
j = '''
    {
        "a": 100,
        "b": [1, 2, 3],
        "c": "python",
        "d": {
            "e": 4,
            "f": 5.5
        }
    }
'''

# %%
class CustomDecoder(json.JSONDecoder):
    def decode(self, arg):
        print("decode: ", type(arg), arg)
        return "a simple string object"

# %%
result = json.loads(j, cls=CustomDecoder)
# Out:
# decode:  <class 'str'>
#     {
#         "a": 100,
#         "b": [1, 2, 3],
#         "c": "python",
#         "d": {
#             "e": 4,
#             "f": 5.5
#         }
#     }

# %%
result
# Out:
# 'a simple string object'

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __init__(self):
        return f'Point(x={self.x}, y={self.y}'

# %%
j_points = '''
{
    "points": [
        [10, 20],
        [-1, -2],
        [0.5, 0.5]
    ]
}
'''

j_other = '''
{
    "a": 1,
    "b": 2
}
'''

# %%
class CustomDecoder(json.JSONDecoder):
    def decode(self, arg):
        if 'points' in arg:
            obj = json.loads(arg)
            return "parsing object for points"
        else:
            return super().decode(arg)

# %%
json.loads(j_points, cls=CustomDecoder)
# Out:
# 'parsing object for points'

# %%
json.loads(j_other, cls=CustomDecoder)
# Out:
# {'a': 1, 'b': 2}

# %%
class CustomDecoder(json.JSONDecoder):
    def decode(self, arg):
        obj = json.loads(arg)
        if 'points' in obj:
            obj['points'] = [Point(x, y) for x, y in obj['points']]
        return obj

# %%
json.loads(j_points, cls=CustomDecoder)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 json.loads(j_points, cls=CustomDecoder)
#
# File /usr/lib/python3.12/json/__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     357 if parse_constant is not None:
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# Cell In[13], line 5, in CustomDecoder.decode(self, arg)
#       3 obj = json.loads(arg)
#       4 if 'points' in obj:
# ----> 5     obj['points'] = [Point(x, y) for x, y in obj['points']]
#       6 return obj
#
# TypeError: Point.__init__() takes 1 positional argument but 3 were given
