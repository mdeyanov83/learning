# %% [markdown]
# ### Marshmallow

# %%
class Person:
    def __init__(self, first_name, last_name, dob, height):
        self.first_name = first_name
        self.last_name = last_name
        self.dob = dob
        self.height = height

    def __repr__(self):
        return f'Person({self.first_name}, {self.last_name}, {self.dob}, {self.height})'

# %%
from datetime import date

# %%
p1 = Person('John', 'Cleese', date(1939, 10, 27), 182)

# %%
p1
# Out:
# Person(John, Cleese, 1939-10-27, 182)

# %%
from marshmallow import Schema, fields

# %%
class PersonSchema(Schema):
    first_name = fields.Str()
    last_name = fields.Str()
    dob = fields.Date()
    height = fields.Int()

# %%
person_schema = PersonSchema()

# %%
person_schema.dump(p1)
# Out:
# {'first_name': 'John',
#  'last_name': 'Cleese',
#  'dob': '1939-10-27',
#  'height': 182}

# %%
data = person_schema.dump(p1)

# %%
data
# Out:
# {'first_name': 'John',
#  'last_name': 'Cleese',
#  'dob': '1939-10-27',
#  'height': 182}

# %%
print(type(p1), p1)
print(type(data), data)
# Out:
# <class '__main__.Person'> Person(John, Cleese, 1939-10-27, 182)
# <class 'dict'> {'first_name': 'John', 'last_name': 'Cleese', 'dob': '1939-10-27', 'height': 182}

# %%
type(data['height'])
# Out:
# int

# %%
data_json = person_schema.dumps(p1)

# %%
data_json
# Out:
# '{"first_name": "John", "last_name": "Cleese", "dob": "1939-10-27", "height": 182}'

# %%
type(data_json)
# Out:
# str

# %%
from collections import namedtuple

# %%
PT = namedtuple('PT', 'first_name, last_name, dob, height')

# %%
p2 = PT('Eric', 'Idle', date(1943, 3, 29), 178)

# %%
p2
# Out:
# PT(first_name='Eric', last_name='Idle', dob=datetime.date(1943, 3, 29), height=178)

# %%
person_schema.dumps(p2)
# Out:
# '{"first_name": "Eric", "last_name": "Idle", "dob": "1943-03-29", "height": 178}'

# %%
PT2 = namedtuple('PT2', 'first_name, last_name, age')
p3 = PT2('Michael', 'Palin', 75)

# %%
person_schema.dumps(p3)
# Out:
# '{"first_name": "Michael", "last_name": "Palin"}'

# %%
person_partial = PersonSchema(only=('first_name', 'last_name'))

# %%
person_schema.dumps(p1)
# Out:
# '{"first_name": "John", "last_name": "Cleese", "dob": "1939-10-27", "height": 182}'

# %%
person_partial.dumps(p1)
# Out:
# '{"first_name": "John", "last_name": "Cleese"}'

# %%
person_partial2 = PersonSchema(exclude=['dob'])

# %%
person_partial2.dumps(p1)
# Out:
# '{"first_name": "John", "last_name": "Cleese", "height": 182}'

# %%
class PersonSchema(Schema):
    first_name = fields.Str()
    last_name = fields.Str()
    dob = fields.Date()
    height = fields.Int()

# %%
p4 = Person(100, None, 200, 'abc')

# %%
person_schema.dumps(p4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 person_schema.dumps(p4)
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:589, in Schema.dumps(self, obj, many, *args, **kwargs)
#     576 def dumps(self, obj: typing.Any, *args, many: bool | None = None, **kwargs):
#     577     """Same as :meth:`dump`, except return a JSON-encoded string.
#     578
#     579     :param obj: The object to serialize.
#    (...)    587         if ``obj`` is invalid.
#     588     """
# --> 589     serialized = self.dump(obj, many=many)
#     590     return self.opts.render_module.dumps(serialized, *args, **kwargs)
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:567, in Schema.dump(self, obj, many)
#     564 else:
#     565     processed_obj = obj
# --> 567 result = self._serialize(processed_obj, many=many)
#     569 if self._hooks[POST_DUMP]:
#     570     result = self._invoke_dump_processors(
#     571         POST_DUMP, result, many=many, original_data=obj
#     572     )
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/schema.py:536, in Schema._serialize(self, obj, many)
#     534 ret = self.dict_class()
#     535 for attr_name, field_obj in self.dump_fields.items():
# --> 536     value = field_obj.serialize(attr_name, obj, accessor=self.get_attribute)
#     537     if value is missing:
#     538         continue
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/fields.py:328, in Field.serialize(self, attr, obj, accessor, **kwargs)
#     326 else:
#     327     value = None
# --> 328 return self._serialize(value, attr, obj, **kwargs)
#
# File /opt/venv/lib/python3.12/site-packages/marshmallow/fields.py:1243, in _TemporalField._serialize(self, value, attr, obj, **kwargs)
#    1241 format_func = self.SERIALIZATION_FUNCS.get(data_format)
#    1242 if format_func:
# -> 1243     return format_func(value)
#    1244 return value.strftime(data_format)
#
# TypeError: descriptor 'isoformat' for 'datetime.date' objects doesn't apply to a 'int' object

# %%
class Movie:
    def __init__(self, title, year, actors):
        self.title = title
        self.year = year
        self.actors = actors

# %%
class MovieSchema(Schema):
    title = fields.Str()
    year = fields.Integer()
    actors = fields.Nested(PersonSchema, many=True)

# %%
p1, p2
# Out:
# (Person(John, Cleese, 1939-10-27, 182),
#  PT(first_name='Eric', last_name='Idle', dob=datetime.date(1943, 3, 29), height=178))

# %%
parrot = Movie('Parrot Sketch', 1989, [p1, PT('Michael', 'Palin', date(1943, 5, 5), 177)])

# %%
parrot

# %%
MovieSchema().dumps(parrot)
# Out:
# '{"title": "Parrot Sketch", "year": 1989, "actors": [{"first_name": "John", "last_name": "Cleese", "dob": "1939-10-27", "height": 182}, {"first_name": "Michael", "last_name": "Palin", "dob": "1943-05-05", "height": 177}]}'

# %%
class PersonSchema(Schema):
    first_name = fields.Str()
    last_name = fields.Str()
    dob = fields.Date()
    height = fields.Int()

# %%
person_scheam = PersonSchema()

# %%
person_schema.load(dict(first_name='John',
                        last_name='Cleese',
                        dob='1939-10-27',
                        height=178))
# Out:
# {'first_name': 'John',
#  'last_name': 'Cleese',
#  'dob': datetime.date(1939, 10, 27),
#  'height': 178}
