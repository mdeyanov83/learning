# %% [markdown]
# ### JSON Serialization

# %%
import json

# %%
d1 = {'a': 100, 'b': 200}

# %%
d1_json = json.dumps(d1)

# %%
d1_json
# Out:
# '{"a": 100, "b": 200}'

# %%
type(d1_json)
# Out:
# str

# %%
print(json.dumps(d1, indent=2))
# Out:
# {
#   "a": 100,
#   "b": 200
# }

# %%
d2 = json.loads(d1_json)

# %%
d2 == d1
# Out:
# True

# %%
d1 is d2
# Out:
# False

# %%
d1 = {1: 100, 2: 200}

# %%
d1_json = json.dumps(d1)

# %%
d1_json
# Out:
# '{"1": 100, "2": 200}'

# %%
d2 = json.loads(d1_json)

# %%
d2
# Out:
# {'1': 100, '2': 200}

# %%
d1 == d2
# Out:
# False

# %%
d_json = '''
{
    "name": "John Cleese",
    "age": 82,
    "heigh": 1.96,
    "walksFunny": true,
    "sketches": [
        {
        "title": "Dead Parrot",
        "costars": ["Michael Palin"]
        },
        {
        "title": "Ministry of Silly Walks",
        "costars": ["Michael Palin", "Terry Jones"]
        }
    ],
    "boring": null
}
'''

# %%
type(d_json)
# Out:
# str

# %%
d = json.loads(d_json)

# %%
d
# Out:
# {'name': 'John Cleese',
#  'age': 82,
#  'heigh': 1.96,
#  'walksFunny': True,
#  'sketches': [{'title': 'Dead Parrot', 'costars': ['Michael Palin']},
#   {'title': 'Ministry of Silly Walks',
#    'costars': ['Michael Palin', 'Terry Jones']}],
#  'boring': None}

# %%
from pprint import pprint
pprint(d)
# Out:
# {'age': 82,
#  'boring': None,
#  'heigh': 1.96,
#  'name': 'John Cleese',
#  'sketches': [{'costars': ['Michael Palin'], 'title': 'Dead Parrot'},
#               {'costars': ['Michael Palin', 'Terry Jones'],
#                'title': 'Ministry of Silly Walks'}],
#  'walksFunny': True}

# %%
print(d)
# Out:
# {'name': 'John Cleese', 'age': 82, 'heigh': 1.96, 'walksFunny': True, 'sketches': [{'title': 'Dead Parrot', 'costars': ['Michael Palin']}, {'title': 'Ministry of Silly Walks', 'costars': ['Michael Palin', 'Terry Jones']}], 'boring': None}

# %%
print(d['age'], )
