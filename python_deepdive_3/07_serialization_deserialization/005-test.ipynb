# %% [markdown]
# ### JSON Serialization

# %%
import json

# %%
d1 = {'a': 100, 'b': 200}

# %%
d1_json = json.dumps(d1)

# %%
d1_json
# Out:
# '{"a": 100, "b": 200}'

# %%
type(d1_json)
# Out:
# str

# %%
print(json.dumps(d1, indent=2))
# Out:
# {
#   "a": 100,
#   "b": 200
# }
