# %% [markdown]
# ### YAML Format

# %%
import yaml
from yaml import Loader

# %%
data = '''
---
title: Parrot Sketch
year: 1989
actors:
    - first_name: John
      last_name: Cleese
      dob: 1939-10-27
    - first_name: Michael
      last_name: Palin
      dob: 1943-05-05
'''

# %%
d = yaml.load(data, Loader=Loader)
