# %% [markdown]
# ### Common Set Operations

# %%
s = {1, 2, 3}

# %%
len(s)
# Out:
# 3

# %%
1 in s
# Out:
# True

# %%
4 in s
# Out:
# False

# %%
from timeit import timeit

# %%
n = 100_000
s = {i for i in range(n)}
l = [i for i in range(n)]
d = {i: None for i in range(n)}

# %%
number = 1_000_000
search = 9
t_list = timeit(f'{search} in l', globals=globals(), number=number)
t_set = timeit(f'{search} in s', globals=globals(), number=number)
t_dict = timeit(f'{search} in d', globals=globals(), number=number)
print(t_list)
print(t_set)
print(t_dict)
# Out:
# 0.16278419999980542
# 0.030475116000161506
# 0.03387388400005875

# %%
number = 10_000
search = 99_999
t_list = timeit(f'{search} in l', globals=globals(), number=number)
t_set = timeit(f'{search} in s', globals=globals(), number=number)
t_dict = timeit(f'{search} in d', globals=globals(), number=number)
print(t_list)
print(t_set)
print(t_dict)
# Out:
# 10.912240382000164
# 0.0004652370002986572
# 0.0005325420002009196

# %%
number = 10_000
search = -1
t_list = timeit(f'{search} not in l', globals=globals(), number=number)
t_set = timeit(f'{search} not in s', globals=globals(), number=number)
t_dict = timeit(f'{search} not in d', globals=globals(), number=number)
print(t_list)
print(t_set)
print(t_dict)
# Out:
# 10.387437080000382
# 0.0002243180001642031
# 0.00025972100002036314

# %%
print(d.__sizeof__())
print(s.__sizeof__())
print(l.__sizeof__())
# Out:
# 5242944
# 4194504
# 800968
