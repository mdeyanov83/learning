# %% [markdown]
# ### Update Operations

# %%
s1 = {1, 2, 3}
s2 = {2, 3, 4}

# %%
print(s1, id(s1))
print(s2, id(s2))
# Out:
# {1, 2, 3} 140187735804384
# {2, 3, 4} 140187735805728

# %%
s1 = s1 & s2

# %%
print(s1, id(s1))
print(s2, id(s2))
# Out:
# {2, 3} 140187736751712
# {2, 3, 4} 140187735805728

# %%
globals()['s1']
# Out:
# {2, 3}

# %%
id(globals()['s1'])
# Out:
# 140187736751712

# %%
s1 = {1, 2, 3}
s2 = {2, 3, 4}

# %%
print(id(s1))
# Out:
# 140187735812224

# %%
s1 |= s2

# %%
print(s1, id(s1))
# Out:
# {1, 2, 3, 4} 140187735812224

# %%
s1 = {1, 2, 3}
s2 = {2, 3, 4}
print(id(s1))
s1.update(s2)
print(s1, id(s1))
# Out:
# 140187735805728
# {1, 2, 3, 4} 140187735805728

# %%
s1 = {1, 2, 3}
s2 = {2, 3, 4}
print(id(s1))
s1 &= s2
print(id(s1), s1)
# Out:
# 140187735812000
# 140187735812000 {2, 3}

# %%
s1 = {1, 2, 3}
s2 = {2, 3, 4}
print(id(s1))
s1.intersection_update(s2)
print(id(s1), s1)
# Out:
# 140187735809088
# 140187735809088 {2, 3}

# %%
s1 = {1, 2, 3, 4}
s2 = {2, 3}
print(id(s1))
s1 -= s2
print(s1, id(s1))
# Out:
# 140187735814016
# {1, 4} 140187735814016

# %%
s1 = {1, 2, 3, 4}
s2 = {2, 3}
print(id(s1))
s1.difference_update(s2)
print(s1, id(s1))
# Out:
# 140187735805728
# {1, 4} 140187735805728

# %%
s1 = {1, 2, 3, 4}
s2 = {2, 3}
s3 = {3, 4}
result = (s1 - s2) - s3
print(result)

s1 -= s2 - s3
print(s1)
# Out:
# {1}
# {1, 3, 4}

# %%
s1 = {1, 2, 3, 4}
s2 = {2, 3}
s3 = {3, 4}
result = s1 - (s2 - s3)
print(result)

s1 -= s2 - s3
print(s1)
# Out:
# {1, 3, 4}
# {1, 3, 4}

# %%
s1 = {1, 2, 3, 4}
s2 = {2, 3}
s3 = {3, 4}
result = s1 - (s2 - s3)
print(result)

s1 -= s2 - s3
print(s1)

s1 = {1, 2, 3, 4}
s2 = {2, 3}
s3 = {3, 4}

s1.difference_update(s2, s3)
print(s1)
# Out:
# {1, 3, 4}
# {1, 3, 4}
# {1}

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {4, 5, 6, 7}
s1 ^ s2
# Out:
# {1, 2, 3, 6, 7}

# %%
print(id(s1))
s1 ^= s2
print(id(s1), s1)
# Out:
# 140187735814016
# 140187735814016 {1, 2, 3, 6, 7}

# %%
s1 = {1, 2, 3}
s2 = {3, 4, 5}
s3 = {5, 6, 7}

print(id(s1))
s1 |= s2 | s3
print(id(s1), s1)
# Out:
# 140187735809760
# 140187735809760 {1, 2, 3, 4, 5, 6, 7}

# %%
s1 = {1, 2, 3}
s1.update([3, 4, 5], (6, 7, 8), 'abc')

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 'a', 'b', 'c'}

# %%
s1 = {1, 2, 3}
s1 |= set([3, 4, 5]) | set((6, 7, 8)) | set('abc')

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 'a', 'b', 'c'}

# %%
def combine(string, target):
    target.update(string.split(' '))

# %%
def cleanup(combined):
    words = {'the', 'and', 'a', 'or', 'is', 'of'}
    combined -= words

# %%
result = set()
combine('lumberjacks sleep all night', result)
combine('the minisstry of silly walks', result)
combine('this parrot is a late parrot', result)
cleanup(result)
print(result)
# Out:
# {'lumberjacks', 'this', 'minisstry', 'parrot', 'night', 'walks', 'silly', 'sleep', 'late', 'all'}

# %%
def gen_read_data():
    yield ['Paris', 'Beijing', 'New York', 'London', 'Madrid', 'Mumbai']
    yield ['Hyderabad', 'New York', 'Milan', 'Phoenix', 'Berlin', 'Cairo']
    yield ['Stockholm', 'Cairo', 'Paris', 'Barcelona', 'San Francisco']

# %%
data = gen_read_data()
next(data)
# Out:
# ['Paris', 'Beijing', 'New York', 'London', 'Madrid', 'Mumbai']

# %%
next(data)
# Out:
# ['Hyderabad', 'New York', 'Milan', 'Phoenix', 'Berlin', 'Cairo']

# %%
next(data)
# Out:
# ['Stockholm', 'Cairo', 'Paris', 'Barcelona', 'San Francisco']

# %%
next(data)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 next(data)
#
# StopIteration:

# %%
def filter_incoming(*cities, data_set):
    data_set.difference_update(cities)

# %%
result = set()
data = gen_read_data()
for page in data:
    result.update(page)
    filter_incoming('Paris', 'London', data_set=result)
print(result)
# Out:
# {'Beijing', 'Milan', 'San Francisco', 'Mumbai', 'Stockholm', 'Madrid', 'Hyderabad', 'New York', 'Berlin', 'Barcelona', 'Cairo', 'Phoenix'}
