# %% [markdown]
# ### Update Operations

# %%
s1 = {1, 2, 3}
s2 = {2, 3, 4}

# %%
print(s1, id(s1))
print(s2, id(s2))
# Out:
# {1, 2, 3} 140187735804384
# {2, 3, 4} 140187735805728

# %%
s1 = s1 & s2

# %%
print(s1, id(s1))
print(s2, id(s2))
# Out:
# {2, 3} 140187736751712
# {2, 3, 4} 140187735805728
