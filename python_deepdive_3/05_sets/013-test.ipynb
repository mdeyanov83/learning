# %% [markdown]
# ### Copying Sets

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f'Person(name={self.name})'

# %%
p1 = Person('John')
p2 = Person('Eric')

# %%
hash(p1)
# Out:
# 8774323371667

# %%
hash(p2)
# Out:
# 8774323371367

# %%
s1 = {p1, p2}

# %%
s2 = s1.copy()

# %%
s1 is s2
# Out:
# False

# %%
s2
# Out:
# {Person(name=Eric), Person(name=John)}

# %%
p1 in s1
# Out:
# True

# %%
p1 in s2
# Out:
# True

# %%
s3 = {*s1}

# %%
s3
# Out:
# {Person(name=Eric), Person(name=John)}

# %%
s1 is s3
# Out:
# False

# %%
s1 == s3
# Out:
# True

# %%
s1, s2, s3
# Out:
# ({Person(name=Eric), Person(name=John)},
#  {Person(name=Eric), Person(name=John)},
#  {Person(name=Eric), Person(name=John)})

# %%
p1.name = 'John Cleese'

# %%
p1
# Out:
# Person(name=John Cleese)

# %%
s1, s2, s3
# Out:
# ({Person(name=Eric), Person(name=John Cleese)},
#  {Person(name=Eric), Person(name=John Cleese)},
#  {Person(name=Eric), Person(name=John Cleese)})

# %%
hash(p1)
# Out:
# 8774323371667

# %%
s4 = set(s1)

# %%
s1 == s4
# Out:
# True

# %%
s1 is s4
# Out:
# False

# %%
from copy import deepcopy

# %%
s5 = deepcopy(s1)

# %%
s5
# Out:
# {Person(name=Eric), Person(name=John Cleese)}

# %%
s1 is s5
# Out:
# False

# %%
s1 == s5
# Out:
# False

# %%
[(o, id(o)) for o in s1]
# Out:
# [(Person(name=John Cleese), 140389173946672),
#  (Person(name=Eric), 140389173941872)]

# %%
[(o, id(o)) for o in s2]
# Out:
# [(Person(name=John Cleese), 140389173946672),
#  (Person(name=Eric), 140389173941872)]
