# %% [markdown]
# ## Keyword Arguments

# %%
def func1(a, b, c):
    print(a, b, c)

# %%
func1(1, 2, 3)
# Out:
# 1 2 3

# %%
func1(1, c=3, b=2)
# Out:
# 1 2 3

# %%
func1(c=3, b=2, a=1)
# Out:
# 1 2 3

# %%
def func1(a, b, *args, d):
    print
