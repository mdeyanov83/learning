# %% [markdown]
# ## Unpacking Iterables

# %%
a = (1,'a', True)

# %%
type(a)
# Out:
# tuple

# %%
a = (1,2,3)

# %%
type(a)
# Out:
# tuple

# %%
a = 1, 2, 3

# %%
type(a)
# Out:
# tuple

# %%
a = (1)

# %%
type(a)
# Out:
# int

# %%
a = 1,

# %%
type(a)
# Out:
# tuple

# %%
a = (1,_)

# %%
type(a)
# Out:
# tuple

# %%
a = ()

# %%
type(a)
# Out:
# tuple
