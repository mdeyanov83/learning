# %% [markdown]
# ## Unpacking Iterables

# %%
a = (1,'a', True)

# %%
type(a)
# Out:
# tuple

# %%
a = (1,2,3)

# %%
type(a)
# Out:
# tuple

# %%
a = 1, 2, 3

# %%
type(a)
# Out:
# tuple

# %%
a = (1)

# %%
type(a)
# Out:
# int

# %%
a = 1,

# %%
type(a)
# Out:
# tuple

# %%
a = (1,_)

# %%
type(a)
# Out:
# tuple

# %%
a = ()

# %%
type(a)
# Out:
# tuple

# %%
a, b, c = [1, 'a', 3.14]

# %%
print(a, b, c)
# Out:
# 1 a 3.14

# %%
(a, b, c) = [1,2,3]

# %%
print(a, b, c)
# Out:
# 1 2 3

# %%
(a, b) = (1, 2)

# %%
a
b
# Out:
# 2

# %%
a
# Out:
# 1

# %%
a, b = 10, 20

# %%
print(a, b)
# Out:
# 10 20

# %%
a, b, c = 10, 20, 30

# %%
print(a, b, c)
# Out:
# 10 20 30

# %%
a, b, c,
