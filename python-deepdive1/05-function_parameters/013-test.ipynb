# %% [markdown]
# ## **kwargs

# %%
def func(**others):
    print(others)

# %%
func(a=1, b=2, c=3)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
def func(*args, **kwargs):
    print(args)
    print(kwargs)

# %%
func(1, 2, 3, 4, x=100, y=200)
# Out:
# (1, 2, 3, 4)
# {'x': 100, 'y': 200}

# %%
def func(a, b, *, d, **kwargs):
    print(a)
    print(b)
    print(d)
    print(kwargs)

# %%
func(1, 2, x=100, y=300, d=20)
# Out:
# 1
# 2
# 20
# {'x': 100, 'y': 300}

# %%
def func(a, b, **kwargs):
    print(a)
    print(b)
    print(kwargs)

# %%
func(1, 2, x=100, y=300)
# Out:
# 1
# 2
# {'x': 100, 'y': 300}
