# %% [markdown]
# ## Extended Unpacking

# %%
l = [1, 2, 3, 4, 5, 6]

# %%
a = l[0]
b = l[1:]
print(a)
print(b)
# Out:
# 1
# [2, 3, 4, 5, 6]

# %%
a, b = l[0], l[1:]
print(a)
print(b)
# Out:
# 1
# [2, 3, 4, 5, 6]

# %%
a, *b = l

# %%
a
# Out:
# 1

# %%
b
# Out:
# [2, 3, 4, 5, 6]
