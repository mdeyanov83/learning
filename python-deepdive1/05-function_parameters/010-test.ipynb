# %% [markdown]
# ## *args

# %%
a, b, *c = 10, 20, 'a', 'b'

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# ['a', 'b']

# %%
def func1(a, b, *args):
    print(a)
    print(b)
    print(args)

# %%
func1(10, 20)
# Out:
# 10
# 20
# ()

# %%
func1(10, 20, 1, 2, 3)
# Out:
# 10
# 20
# (1, 2, 3)

# %%
def avg(*args):
    count = len(args)
    total = sum(args)
    if count == 0:
        return 0
    else:
        return total/count

# %%
avg()
# Out:
# 0

# %%
avg(10,20)
# Out:
# 15.0

# %%
avg(2, 3, 4, 4)
# Out:
# 3.25

# %%
def avg(*args):
    count = len(args)
    total = sum(args)
    return count and total/count

# %%
avg()
# Out:
# 0

# %%
avg(1, 2, 3, 4, 4, 4, 4, 5, 10, 16, 2, 4)
# Out:
# 4.916666666666667

# %%
def avg(a, *args):
    count = len(args) + 1
    total = sum(args) + a
    return total/count

# %%
avg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 avg()
#
# TypeError: avg() missing 1 required positional argument: 'a'

# %%
avg(1, 2, 3)
# Out:
# 2.0

# %%
def func1(a, b, c):
    print(a)
    print(b)
    print(c)

# %%
l = [10, 20, 30]

# %%
func1(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 func1(l)
#
# TypeError: func1() missing 2 required positional arguments: 'b' and 'c'

# %%
func1(*l)
# Out:
# 10
# 20
# 30
