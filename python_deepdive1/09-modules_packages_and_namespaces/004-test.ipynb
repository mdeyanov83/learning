# %% [markdown]
# ### Imports and `importlib`

# %%
import sys

# %%
sys
# Out:
# <module 'sys' (built-in)>

# %%
import collections

# %%
collections
# Out:
# <module 'collections' from '/usr/lib/python3.12/collections/__init__.py'>

# %%
mod_name = 'math'

# %%
import mod_name
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import mod_name
#
# ModuleNotFoundError: No module named 'mod_name'

# %%
import importlib

# %%
importlib
# Out:
# <module 'importlib' from '/usr/lib/python3.12/importlib/__init__.py'>

# %%
importlib.import_module(mod_name)
# Out:
# <module 'math' (built-in)>

# %%
'math' in sys.modules
# Out:
# True

# %%
'fractions' in sys.modules
# Out:
# True

# %%
math.sqrt(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 math.sqrt(2)
#
# NameError: name 'math' is not defined

# %%
'math' in globals()
# Out:
# False

# %%
# import math as math2
# math2 = sys.modules['math']
math2 = importlib.import_module(mod_name)

# %%
math2.sqrt(2)
# Out:
# 1.4142135623730951

# %%
'math2' in globals()
# Out:
# True

# %%
id(math2)
# Out:
# 140711056297152

# %%
id(sys.modules['math'])
# Out:
# 140711056297152

# %%
importlib
# Out:
# <module 'importlib' from '/usr/lib/python3.12/importlib/__init__.py'>

# %%
fractions = importlib.import_module('fractions')

# %%
fractions
# Out:
# <module 'fractions' from '/usr/lib/python3.12/fractions.py'>

# %% [markdown]
# - Finders
# - Loaderes
# - finder + loader == importer

# %%
import math
import fractions
import module1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 3
#       1 import math
#       2 import fractions
# ----> 3 import module1
#
# ModuleNotFoundError: No module named 'module1'

# %%
fractions.__spec__
# Out:
# ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ff9d6f9f0e0>, origin='/usr/lib/python3.12/fractions.py')

# %%
sys.meta_path
# Out:
# [<_distutils_hack.DistutilsMetaFinder at 0x7ff9d8972840>,
#  _frozen_importlib.BuiltinImporter,
#  _frozen_importlib.FrozenImporter,
#  _frozen_importlib_external.PathFinder,
#  <six._SixMetaPathImporter at 0x7ff9d75604a0>]

# %%
import math
math.__spec__
# Out:
# ModuleSpec(name='math', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in')

# %%
import module1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import module1
#
# ModuleNotFoundError: No module named 'module1'

# %%
importlib.util.find_spec('decimal')
# Out:
# ModuleSpec(name='decimal', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ff9d75329c0>, origin='/usr/lib/python3.12/decimal.py')

# %%
with open('module1.py', 'w') as code_file:
    code_file.write("print('running module1.py...')\n")
    code_file.write('a=100\n')

# %%
importlib.util.find_spec('module1')
# Out:
# ModuleSpec(name='module1', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ff9cc4287d0>, origin='/workspaces/LocalDev/learning/python_deepdive1/09-modules_packages_and_namespaces/module1.py')

# %%
import module1
# Out:
# running module1.py...

# %%
'module1' in globals()
# Out:
# True

# %%
module1.a
# Out:
# 100

# %%
import os

# %%
ext_module_path = '\workspaces\LocalDev\python_deepdive1'

# %%
ext_module_path
# Out:
# '\\workspaces\\LocalDev\\python_deepdive1'

# %%
file_abs_path = os.path.join(ext_module_path, 'module2.py')

# %%
file_abs_path
# Out:
# '\\workspaces\\LocalDev\\python_deepdive1/module2.py'

# %%
with open(file_abs_path, 'w') as code_file:
    code_file.write("print('running module2.py...')\n")
    code_file.write("x = 'python'\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 with open(file_abs_path, 'w') as code_file:
#       2     code_file.write("print('running module2.py...')\n")
#       3     code_file.write("x = 'python'\n")
#
# File /opt/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\workspaces\\LocalDev\\python_deepdive1/module2.py'
