# %% [markdown]
# ### Imports and `importlib`

# %%
import sys

# %%
sys
# Out:
# <module 'sys' (built-in)>

# %%
import collections

# %%
collections
# Out:
# <module 'collections' from '/usr/lib/python3.12/collections/__init__.py'>

# %%
mod_name = 'math'
