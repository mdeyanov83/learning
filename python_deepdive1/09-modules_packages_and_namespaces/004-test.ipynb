# %% [markdown]
# ### Imports and `importlib`

# %%
import sys

# %%
sys
# Out:
# <module 'sys' (built-in)>

# %%
import collections

# %%
collections
# Out:
# <module 'collections' from '/usr/lib/python3.12/collections/__init__.py'>

# %%
mod_name = 'math'

# %%
import mod_name
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import mod_name
#
# ModuleNotFoundError: No module named 'mod_name'

# %%
import importlib

# %%
importlib
# Out:
# <module 'importlib' from '/usr/lib/python3.12/importlib/__init__.py'>

# %%
importlib.import_module(mod_name)
# Out:
# <module 'math' (built-in)>

# %%
'math' in sys.modules
# Out:
# True

# %%
'fractions' in sys.modules
# Out:
# True

# %%
math.sqrt(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 math.sqrt(2)
#
# NameError: name 'math' is not defined

# %%
'math' in globals()
# Out:
# False

# %%
# import math as math2
# math2 = sys.modules['math']
math2 = importlib.import_module(mod_name)

# %%
math2.sqrt(2)
# Out:
# 1.4142135623730951

# %%
'math2' in globals()
# Out:
# True

# %%
id(math2)
# Out:
# 140711056297152

# %%
id(sys.modules['math'])
# Out:
# 140711056297152

# %%
importlib
# Out:
# <module 'importlib' from '/usr/lib/python3.12/importlib/__init__.py'>

# %%
fractions = importlib.import_module('fractions')

# %%
fractions
# Out:
# <module 'fractions' from '/usr/lib/python3.12/fractions.py'>

# %% [markdown]
# - Finders
# - Loaderes
# - finder + loader == importer

# %%
import math
import fractions
import module1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 3
#       1 import math
#       2 import fractions
# ----> 3 import module1
#
# ModuleNotFoundError: No module named 'module1'

# %%
fractions.__spec__
# Out:
# ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ff9d6f9f0e0>, origin='/usr/lib/python3.12/fractions.py')

# %%
sys.meta_path
# Out:
# [<_distutils_hack.DistutilsMetaFinder at 0x7ff9d8972840>,
#  _frozen_importlib.BuiltinImporter,
#  _frozen_importlib.FrozenImporter,
#  _frozen_importlib_external.PathFinder,
#  <six._SixMetaPathImporter at 0x7ff9d75604a0>]

# %%
import math
math.__spec__
# Out:
# ModuleSpec(name='math', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in')

# %%
import module1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import module1
#
# ModuleNotFoundError: No module named 'module1'

# %%
importlib.util.find_spec('decimal')
# Out:
# ModuleSpec(name='decimal', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ff9d75329c0>, origin='/usr/lib/python3.12/decimal.py')

# %%
with open('module1.py', 'w') as code_file:
    code_file.write("print('running module1.py...')\n")
    code_file.write('a=100\n')
