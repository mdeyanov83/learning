# %% [markdown]
# ### Reloading Modules

# %%
import os

def create_module_file(module_name, **kwargs):
    '''Create a module file named <module_name>.py
    Module has a single function (print_values) that will print
    out the supplied (stringified) kwargs
    '''

    module_file_name = f'{module_name}.py'
    module_rel_file_path = module_file_name
    module_abs_file_path = os.path.abspath(module_rel_file_path)

    with open(module_abs_file_path, 'w') as f:
        f.write(f'# {module_name}.py\n\n')
        f.write(f"print('running {module_file_name}...')\n\n")
        f.write(f'def print_values():\n')
        for key, value in kwargs.items():
            f.write(f"\tprint('{str(key)}', '{str(value)}')\n")

# %%
create_module_file('test1', k1=10, k2='python')

# %%
import test1
# Out:
# running test1.py...

# %%
test1.__file__
# Out:
# '/workspaces/LocalDev/learning/python_deepdive1/09-modules_packages_and_namespaces/test1.py'

# %%
test1.print_values()
# Out:
# k1 10
# k2 python

# %%
create_module_file('test1', k1=10, k2='python', k3='cheese')

# %%
import test1

# %%
test1.print_values()
# Out:
# k1 10
# k2 python

# %%
id(test1)
# Out:
# 140192091336080

# %%
import sys

# %%
'test1' in sys.modules
# Out:
# True

# %%
del sys.modules['test1']

# %%
'test1' in sys.modules
# Out:
# False

# %%
import test1
# Out:
# running test1.py...

# %%
id(sys.modules['test1'])
# Out:
# 140191536680128

# %%
'test1' in globals()
# Out:
# True

# %%
id(test1)
# Out:
# 140191536680128

# %%
test1.print_values()
# Out:
# k1 10
# k2 python
# k3 cheese

# %%
id(test1), id(sys.modules['test1'])
# Out:
# (140191536680128, 140191536680128)

# %%
create_module_file('test1', k1=10, k2='python', k3='cheese', k4='parrots')

# %%
import importlib

# %%
importlib.reload(test1)
# Out:
# running test1.py...
# <module 'test1' from '/workspaces/LocalDev/learning/python_deepdive1/09-modules_packages_and_namespaces/test1.py'>

# %%
id(test1)
# Out:
# 140191536680128

# %%
id(sys.modules['test1'])
# Out:
# 140191536680128

# %%
test1.print_values()
# Out:
# k1 10
# k2 python
# k3 cheese
# k4 parrots

# %%
create_module_file('test2', k1='python')

# %%
from test2 import print_values

# %%
'test2' in globals(), 'test2' in sys.modules
# Out:
# (False, True)

# %%
print_values
# Out:
# <function test2.print_values()>

# %%
print_values()
# Out:
# k1 python

# %%
create_module_file('test2', k1='python', k2='cheese')

# %%
importlib.reload(test2) # failes because test2 is not in our globals(), only print_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 importlib.reload(test2)
#
# NameError: name 'test2' is not defined

# %%
importlib.reload(sys.modules['test2'])
# Out:
# running test2.py...
# <module 'test2' from '/workspaces/LocalDev/learning/python_deepdive1/09-modules_packages_and_namespaces/test2.py'>

# %%
print_values()
# Out:
# k1 python

# %%
print_values = sys.modules['test2'].print_values

# %%
print_values()
# Out:
# k1 python
# k2 cheese
