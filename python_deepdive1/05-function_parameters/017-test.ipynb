# %% [markdown]
# ## Default Values - Beware!

# %%
from datetime import datetime

# %%
print(datetime.now())
# Out:
# 2025-11-12 14:25:23.047659

# %%
print(datetime.now())
# Out:
# 2025-11-12 14:25:25.542424

# %%
def log(msg, *, dt=datetime.now()):
    print(f"{dt}: {msg}")

# %%
log('message 1', dt='2015-01-01 00:00:00.000')
# Out:
# 2015-01-01 00:00:00.000: message 1

# %%
log('message 2')
# Out:
# 2025-11-12 14:26:24.393611: message 2

# %%
log('message 3')
# Out:
# 2025-11-12 14:28:56.912589: message 3

# %%
def log(msg, *, dt=None):
    dt = dt or datetime.now()
    print(f"{msg}: {dt}")

# %%
log("message")
# Out:
# message: 2025-11-12 14:30:16.583563

# %%
log("message")
# Out:
# message: 2025-11-12 14:30:25.903469

# %%
log("message")
# Out:
# message: 2025-11-12 14:30:31.874464

# %%
log("mesage with specified datetime", dt='2010-01-02')
# Out:
# mesage with specified datetime: 2010-01-02

# %%
my_list = [1, 2, 3]
def func(a=my_list):
    print(a)

# %%
func()
# Out:
# [1, 2, 3]

# %%
func(['a', 'b'])
# Out:
# ['a', 'b']

# %%
func()
# Out:
# [1, 2, 3]

# %%
my_list.append(4)

# %%
func()
# Out:
# [1, 2, 3, 4]
