# %% [markdown]
# ### Decorators Application (Timing)

# %%
def timed(fn):
    from time import perf_counter
    from functools import wraps

    @wraps(fn)
    def inner(*args, **kwargs):
        start = perf_counter()
        result = fn(*args, **kwargs)
        end = perf_counter()
        elapsed = end - start
        args_ = [str(a) for a in args]
        kwargs_ = [f'{k}={v}' for (k, v) in kwargs.items()]
        all_args = args_ + kwargs_
        args_str = ','.join(all_args)
        print(f'{fn.__name__}({args_str}) took {elapsed:.6f}s to run.')
        return result
    return inner

# %% [markdown]
# Calculate fibonacci numbers:
# 1. recursion
# 2. loop
# 3. reduce

# %%
@timed
def calc_recursive_fib(n):
    if n <= 2:
        return 1
    else:
        return calc_recursive_fib(n-1) + calc_recursive_fib(n-2)

# %%
calc_recursive_fib(5)
# Out:
# calc_recursive_fib(2) took 0.000001s to run.
# calc_recursive_fib(1) took 0.000001s to run.
# calc_recursive_fib(3) took 0.000268s to run.
# calc_recursive_fib(2) took 0.000001s to run.
# calc_recursive_fib(4) took 0.000363s to run.
# calc_recursive_fib(2) took 0.000001s to run.
# calc_recursive_fib(1) took 0.000001s to run.
# calc_recursive_fib(3) took 0.000104s to run.
# calc_recursive_fib(5) took 0.000568s to run.
# 5
