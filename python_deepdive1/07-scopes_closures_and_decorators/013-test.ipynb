# %% [markdown]
# ### Decorators Application (Logger, Stacked Decorators)

# %%
def logged(fn):
    from functools import wraps
    from datetime import datetime, timezone

    @wraps(fn)
    def inner(*args, **kwargs):
        run_dt = datetime.now(timezone.utc)
        result = fn(*args, **kwargs)
        print(f'{run_dt}: called {fn.__name__}')
        return result

    return inner

# %%
@logged
def func_1():
    pass

# %%
@logged
def func_2():
    pass

# %%
func_1()
# Out:
# 2025-12-02 11:35:08.245702+00:00: called func_1

# %%
func_2()
# Out:
# 2025-12-02 11:35:14.395745+00:00: called func_2

# %%
def timed(fn):
    from time import perf_counter
    from functools import wraps

    @wraps(fn)
    def inner(*args, **kwargs):
        start = perf_counter()
        result = fn(*args, **kwargs)
        end = perf_counter()
        print(f'{fn.__name__} ran for {end-start:.6f}s')
        return result

    return inner

# %%
@logged
@timed
def fact(n):
    from operator import mul
    from functools import reduce

    return reduce(mul, range(1, n+1))

# %%
fact(3)
# Out:
# fact ran for 0.000009s
# 2025-12-02 11:39:29.290263+00:00: called fact
# 6

# %%
fact(5)
# Out:
# 2025-12-02 11:39:19.001043+00:00: called fact
# 120
