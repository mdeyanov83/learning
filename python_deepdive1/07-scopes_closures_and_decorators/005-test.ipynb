# %% [markdown]
# ### Nonlocal Scopes

# %%
def outer_func():
    x = 'hello'
    def inner_func():
        print(x)
    inner_func()

# %%
outer_func()
# Out:
# hello

# %%
def outer_func():
    x = 'hello'
    def inner1():
        def inner2():
            print(x)
        inner2()
    inner1()

# %%
outer_func()
# Out:
# hello

# %%
def outer_func():
    x = 'hello'
    def inner():
        x = 'python'
        print('inner:', x)
    inner()
    print('outer:', x)

# %%
outer_func()
# Out:
# inner: python
# outer: hello

# %%
def outer_func():
    x = 'hello'

    def inner():
        nonlocal x
        x = 'python'
        print('inner:', x)
    print('outer(before)', x)
    inner()
    print('outer(after):', x)

# %%
outer_func()
# Out:
# outer(before) hello
# inner: python
# outer(after): python

# %%
def outer():
    x = 'hello'
    def inner1():
        def inner2():
            nonlocal x
            x = 'python'
        inner2()
    inner1()
    print(x)

# %%
outer()
# Out:
# python

# %%
def outer():
    x = 'hello'
    def inner1():
        nonlocal x
        x = 'python'
        def inner2():
            nonlocal x
            x = 'monty'
        inner2()
    inner1()
    print(x)

# %%
outer()
# Out:
# monty
