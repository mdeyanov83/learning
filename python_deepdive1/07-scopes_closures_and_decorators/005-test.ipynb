# %% [markdown]
# ### Nonlocal Scopes

# %%
def outer_func():
    x = 'hello'
    def inner_func():
        print(x)
    inner_func()

# %%
outer_func()
# Out:
# hello

# %%
def outer_func():
    x = 'hello'
    print()
