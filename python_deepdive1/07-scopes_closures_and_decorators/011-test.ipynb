# %% [markdown]
# ### Decorators (Part 1)

# %%
def counter(fn):
    count = 0

    def inner(*args, **kwargs):
        nonlocal count
        count += 1
        print(f'Function {fn.__name__} (id={id(fn)}) was called {count} times')
        return fn(*args, **kwargs)

    return inner

# %%
def add(a: int, b: int = 0):
    """
    adds two values
    """
    return a + b

# %%
help(add)
# Out:
# Help on function add in module __main__:
#
# add(a: int, b: int = 0)
#     adds two values

# %%
id(add)
# Out:
# 140454439057696

# %%
add = counter(add)

# %%
id(add)
# Out:
# 140454439056896

# %%
help(add)
# Out:
# Help on function inner in module __main__:
#
# inner(*args, **kwargs)

# %%
add(10, 20)
# Out:
# Function add (id=140454439057696) was called 1 times
# 30

# %%
add(20, 40)
# Out:
# Function add (id=140454439057696) was called 2 times
# 60

# %%
add(10)
# Out:
# Function add (id=140454439057696) was called 3 times
# 10

# %%
def mult(a: int, b:int, c:int = 1, *, d):
    """
    multiplies four values
    """
    return a * b * c * d

# %%
mult(1, 2, 3, d=4)
# Out:
# 24

# %%
mult(1, 2, d=3)
# Out:
# 6

# %%
mult = counter(mult)

# %%
help(mult)
# Out:
# Help on function inner in module __main__:
#
# inner(*args, **kwargs)

# %%
mult(1, 2, 3, d=4)
# Out:
# Function mult (id=140454439600512) was called 1 times
# 24
