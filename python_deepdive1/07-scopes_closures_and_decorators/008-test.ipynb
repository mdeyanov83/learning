# %% [markdown]
# ### Closure Applications (part 1)

# %%
class Averager:
    def __init__(self):
        self.numbers = []

    def add(self, number):
        self.numbers.append(number)
        total = sum(self.numbers)
        count = len(self.numbers)
        return total / count

# %%
a = Averager()

# %%
a.add(10)
# Out:
# 10.0

# %%
a.add(20)
# Out:
# 15.0

# %%
a.add(30)
# Out:
# 20.0

# %%
b = Averager()

# %%
b.add(10)
# Out:
# 10.0
