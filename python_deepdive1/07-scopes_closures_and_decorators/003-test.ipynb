# %% [markdown]
# ### Global and Local Scopes

# %%
a = 10

# %%
def my_func(n):
    c = n ** 2
    return c

# %%
def my_func(n):
    print('global a:', a)
    c = a ** n
    return c

# %%
my_func(2)
# Out:
# global a: 10
# 100

# %%
def my_func(n):
    a = 20
    c = a ** n
    return c

# %%
print(a)
# Out:
# 10

# %%
my_func(2)
# Out:
# 400

# %%
a
# Out:
# 10
