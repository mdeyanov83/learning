# %% [markdown]
# ### Closures

# %%
def outer():
    x = 'python'
    def inner():
        print(x)
    return

# %%
fn = outer()

# %%
fn.__code__.co_freevars
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fn.__code__.co_freevars
#
# AttributeError: 'NoneType' object has no attribute '__code__'

# %%
fn.__closure__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 fn.__closure__
#
# AttributeError: 'NoneType' object has no attribute '__closure__'
