# %% [markdown]
# ### Callables

# %%
callable(print)
# Out:
# True

# %%
print('hello')
# Out:
# hello

# %%
result = print('hello')
# Out:
# hello

# %%
print(result)
# Out:
# None

# %%
l = [1,2,3]

# %%
callable(l.append)
# Out:
# True

# %%
result = l.append(4)

# %%
print(l)
print(result)
# Out:
# [1, 2, 3, 4]
# None

# %%
s = 'abc'

# %%
callable(s.upper)
# Out:
# True
