# %% [markdown]
# ### Sequence Types

# %%
l = [1, 2, 3]
t = (1, 2, 3)
s = 'python'

# %%
l[0]
# Out:
# 1

# %%
t[1]
# Out:
# 2

# %%
s[2]
# Out:
# 't'

# %%
for c in s:
    print(c)
# Out:
# p
# y
# t
# h
# o
# n

# %%
s = {10, 20, 30}
for e in s:
    print(e)
# Out:
# 10
# 20
# 30

# %%
s = {'x', 10, 'a', 'A'}

# %%
for e in s:
    print(e)
# Out:
# A
# a
# 10
# x
