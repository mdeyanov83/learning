# %% [markdown]
# ### Custom Sequences (Part 2b/c)

# %% [markdown]
# #### Part 2b

# %%
from collections import namedtuple

# %%
Point = namedtuple('Point', 'x y')

# %%
p1 = Point(10.5, 3.2)

# %%
p1
# Out:
# Point(x=10.5, y=3.2)

# %%
p1 = Point('abc', [1, 2, 3])

# %%
p1
# Out:
# Point(x='abc', y=[1, 2, 3])

# %%
x, y = p1

# %%
x
# Out:
# 'abc'

# %%
y
# Out:
# [1, 2, 3]

# %%
import numbers

# %%
isinstance(10, numbers.Number)
# Out:
# True

# %%
isinstance('a', numbers.Number)
# Out:
# False

# %%
isinstance(10.5, numbers.Number)
# Out:
# True

# %%
isinstance(10, numbers.Real)
# Out:
# True

# %%
isinstance(10+2j, numbers.Real)
# Out:
# False

# %%
class Point:
    def __init__(self, x, y):
        if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
            self._pt = (x, y)
        else:
            raise TypeError('Point co-ordinates must be real numbers')

    def __repr__(self):
        return f'Point(x={self._pt[0]}, y={self._pt[1]})'

# %%
p1 = Point(10, 2.5)

# %%
p1
# Out:
# Point(x=10, y=2.5)

# %%
p1 = Point('abc', 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 p1 = Point('abc', 10)
#
# Cell In[17], line 6, in Point.__init__(self, x, y)
#       4     self._pt = (x, y)
#       5 else:
# ----> 6     raise TypeError('Point co-ordinates must be real numbers')
#
# TypeError: Point co-ordinates must be real numbers

# %%
x, y = p1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 x, y = p1
#
# TypeError: cannot unpack non-iterable Point object

# %%
class Point:
    def __init__(self, x, y):
        if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
            self._pt = (x, y)
        else:
            raise TypeError('Point co-ordinates must be real numbers')

    def __repr__(self):
        return f'Point(x={self._pt[0]}, y={self._pt[1]})'

    def __len__(self):
        return len(self._pt)

    def __getitem__(self, s):
        return self._pt[s]

# %%
p1 = Point(10, 2)

# %%
x, y = p1

# %%
p2 = Point(*p1)

# %%
p1
# Out:
# Point(x=10, y=2)

# %%
p2
# Out:
# Point(x=10, y=2)

# %%
id(p1), id(p2)
# Out:
# (139894765873600, 139894765989152)

# %%
class Point:
    def __init__(self, x, y):
        if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
            self._pt = (x, y)
        else:
            raise TypeError('Point co-ordinates must be real numbers')

    def __repr__(self):
        return f'Point(x={self._pt[0]}, y={self._pt[1]})'

    def __len__(self):
        return len(self._pt)

    def __getitem__(self, s):
        return self._pt[s]

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        return f'Polygon({self._pts})'

# %%
p = Polygon((0,0), Point(1,1))

# %%
p
# Out:
# Polygon([Point(x=0, y=0), Point(x=1, y=1)])

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

# %%
p = Polygon((0,0), Point(1,1))

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1))

# %%
p1 = Polygon(Point(x=0, y=0), Point(x=1, y=1))

# %%
p1
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1))

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

# %%
p = Polygon((0,0), (1,1), (2,2))

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0]
# Out:
# Point(x=0, y=0)

# %%
p[0:2]
# Out:
# [Point(x=0, y=0), Point(x=1, y=1)]

# %%
p[::-1]
# Out:
# [Point(x=2, y=2), Point(x=1, y=1), Point(x=0, y=0)]

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

# %%
p1 = Polygon((0,0), (1,1))
p2 = Polygon((2,2), (3,3))
id(p1), id(p2)
# Out:
# (139894766747968, 139894765952448)

# %%
result = p1 + p2

# %%
id(result), result
# Out:
# (139894766146224,
#  Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3)))

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def __iadd__(self, other):
        if isinstance(other, Polygon):
            self._pts = self._pts + other._pts
            return self
        else:
            raise TypeError('Can only concatenate with another Polygon')

# %%
p1 = Polygon((0,0), (1,1))
p2 = Polygon((2,2), (3,3))
id(p1), id(p2)
# Out:
# (139894755395248, 139894755395440)

# %%
p1 += p2

# %%
p1
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %%
id(p1)
# Out:
# 139894755395248

# %%
p1 = Polygon((0,0), (1,1))
p2 = Polygon((2,2), (3,3))
id(p1), id(p2)
# Out:
# (139894755399856, 139894755404176)

# %%
p1 = p1.__iadd__(p2)

# %%
id(p1), p1
# Out:
# (139894755399856,
#  Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3)))

# %%
p1 = Polygon((0,0), (1,1))

# %%
p1 += [(2,2), (3,3)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 p1 += [(2,2), (3,3)]
#
# Cell In[68], line 30, in Polygon.__iadd__(self, other)
#      28     return self
#      29 else:
# ---> 30     raise TypeError('Can only concatenate with another Polygon')
#
# TypeError: Can only concatenate with another Polygon

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def __iadd__(self, other):
        if isinstance(other, Polygon):
            points = other._pts
        else:
            points = [Point(*pt) for pt in other]
        self._pts = self._pts + points
        return self

# %%
p1 = Polygon((0,0), (1,1))

# %%
id(p1)
# Out:
# 139894757004816

# %%
p1 += [(2,2), (3,3), Point(4,4)]

# %%
id(p1), p1
# Out:
# (139894757004816,
#  Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4)))

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def __iadd__(self, other):
        if isinstance(other, Polygon):
            points = other._pts
        else:
            points = [Point(*pt) for pt in other]
        self._pts = self._pts + points
        return self

    def append(self, pt):
        self._pts.append(Point(*pt))

    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts += pts._pts
        else:
            points = [Point(*pt) for pt in pts]
            self._pts += points

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))

    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts += pts._pts
        else:
            points = [Point(*pt) for pt in pts]
            self._pts += points

    def __iadd__(self, other):
        self.extend(other)
        return self

# %%
p1 = Polygon((0,0), (1,1))
p2 = Polygon((2,2), (3,3))
print(id(p1), p1)
print(id(p2), p2)
# Out:
# 139894757185616 Polygon(Point(x=0, y=0), Point(x=1, y=1))
# 139894757191280 Polygon(Point(x=2, y=2), Point(x=3, y=3))

# %%
p1.append([10, 10])

# %%
id(p1), p1
# Out:
# (139894757185616, Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=10, y=10)))

# %%
p1.insert(1, Point(-1, -1))

# %%
id(p1), p1
# Out:
# (139894757185616,
#  Polygon(Point(x=0, y=0), Point(x=-1, y=-1), Point(x=1, y=1), Point(x=10, y=10)))

# %%
p1.extend(p2)

# %%
id(p1), p1
# Out:
# (139894757185616,
#  Polygon(Point(x=0, y=0), Point(x=-1, y=-1), Point(x=1, y=1), Point(x=10, y=10), Point(x=2, y=2), Point(x=3, y=3)))

# %%
p1.extend([(0,0), Point(20,20)])

# %%
id(p1), p1
# Out:
# (139894757185616,
#  Polygon(Point(x=0, y=0), Point(x=-1, y=-1), Point(x=1, y=1), Point(x=10, y=10), Point(x=2, y=2), Point(x=3, y=3), Point(x=0, y=0), Point(x=20, y=20)))

# %%
p1.extend(Point(0,0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 p1.extend(Point(0,0))
#
# Cell In[86], line 35, in Polygon.extend(self, pts)
#      33     self._pts += pts._pts
#      34 else:
# ---> 35     points = [Point(*pt) for pt in pts]
#      36     self._pts += points
#
# TypeError: __main__.Point() argument after * must be an iterable, not int

# %% [markdown]
# #### Part 2c

# %%
import numbers

class Point:
    def __init__(self, x, y):
        if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
            self._pt = (x, y)
        else:
            raise TypeError('Point co-ordinates must be real numbers')

    def __repr__(self):
        return f'Point(x={self._pt[0]}, y={self._pt[1]})'

    def __len__(self):
        return len(self._pt)

    def __getitem__(self, s):
        return self._pt[s]

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __setitem__(self, s, value):
        self._pts[s] = [Point(*pt) for pt in value]


    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))

    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts += pts._pts
        else:
            points = [Point(*pt) for pt in pts]
            self._pts += points

    def __iadd__(self, other):
        self.extend(other)
        return self

# %%
p = Polygon((0,0), (1,1), (2,2))
id(p), p
# Out:
# (140275650915184, Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2)))

# %%
p[0:2]
# Out:
# [Point(x=0, y=0), Point(x=1, y=1)]

# %%
p[0:2] = [(10,10), Point(20,20), [30,30]]

# %%
id(p), p
# Out:
# (140275650915184,
#  Polygon(Point(x=10, y=10), Point(x=20, y=20), Point(x=30, y=30), Point(x=2, y=2)))

# %%
p[0]
# Out:
# Point(x=10, y=10)

# %%
p[0] = Point(0,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 p[0] = Point(0,0)
#
# Cell In[7], line 19, in Polygon.__setitem__(self, s, value)
#      18 def __setitem__(self, s, value):
# ---> 19     self._pts[s] = [Point(*pt) for pt in value]
#
# TypeError: __main__.Point() argument after * must be an iterable, not int

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []

    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

    def __len__(self):
        return len(self._pts)

    def __getitem__(self, s):
        return self._pts[s]

    def __setitem__(self, s, value):
        self._pts[s] = [Point(*pt) for pt in value]


    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('Can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))

    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts += pts._pts
        else:
            points = [Point(*pt) for pt in pts]
            self._pts += points

    def __iadd__(self, other):
        self.extend(other)
        return self
