# %% [markdown]
# ### Custom Sequences (Part 2b/c)

# %% [markdown]
# #### Part 2b

# %%
from collections import namedtuple

# %%
Point = namedtuple('Point', 'x y')

# %%
p1 = Point(10.5, 3.2)

# %%
p1
# Out:
# Point(x=10.5, y=3.2)

# %%
p1 = Point('abc', [1, 2, 3])

# %%
p1
# Out:
# Point(x='abc', y=[1, 2, 3])

# %%
x, y = p1

# %%
x
# Out:
# 'abc'

# %%
y
# Out:
# [1, 2, 3]

# %%
import numbers
