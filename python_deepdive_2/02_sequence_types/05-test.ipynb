# %% [markdown]
# ### Mutable Sequences

# %%
l = [1, 2, 3, 4, 5]

# %%
print(id(l))
# Out:
# 140466914435648

# %%
l[0]
# Out:
# 1

# %%
l[0] = 'a'

# %%
l
# Out:
# ['a', 2, 3, 4, 5]

# %%
id(l)
# Out:
# 140466914435648

# %%
l.clear()

# %%
l
# Out:
# []

# %%
id(l)
# Out:
# 140466914435648

# %%
l = [1, 2, 3, 4, 5]

# %%
print(id(l), l)
# Out:
# 140466914440384 [1, 2, 3, 4, 5]

# %%
l = []

# %%
l
# Out:
# []

# %%
id(l)
# Out:
# 140466915250880

# %%
suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']

# %%
alias = suits

# %%
id(alias), id(suits)
# Out:
# (140466915218048, 140466915218048)

# %%
alias.clear()

# %%
alias
# Out:
# []

# %%
suits
# Out:
# []

# %%
suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']

# %%
def something(l):
    l.append('None')

# %%
something(suits)

# %%
suits
# Out:
# ['Spades', 'Hearts', 'Diamonds', 'Clubs', 'None']

# %%
l = [1, 2, 3, 4, 5]

# %%
id(l)
# Out:
# 140466915516352

# %%
l[0:2]
# Out:
# [1, 2]

# %%
l[0:2] = ('a', 'b', 'c', 'd')

# %%
l
# Out:
# ['a', 'b', 'c', 'd', 3, 4, 5]

# %%
id(l)
# Out:
# 140466915516352

# %%
l = l + [4]

# %%
l
# Out:
# ['a', 'b', 'c', 'd', 3, 4, 5, 4]

# %%
id(l)
# Out:
# 140466914745600

# %%
l = [1, 2, 3]

# %%
id(l)
# Out:
# 140466915540288

# %%
l.append(4)

# %%
result = l.append(4)

# %%
type(result)
# Out:
# NoneType

# %%
l
# Out:
# [1, 2, 3, 4, 4]

# %%
id(l)
# Out:
# 140466915540288

# %%
l.append([1, 2, 3])

# %%
l
# Out:
# [1, 2, 3, 4, 4, [1, 2, 3]]

# %%
l = [1, 2, 3]

# %%
id(l)
# Out:
# 140466429639936

# %%
l.extend([4])

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l.extend(['a', 'b', 'c'])

# %%
l
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c']

# %%
id(l)
# Out:
# 140466429639936

# %%
l = [1, 2, 3]

# %%
l.extend({'X', 'a', 'A', 100_000})

# %%
l
# Out:
# [1, 2, 3, 'A', 'X', 100000, 'a']

# %%
l = [1, 2, 3, 4]

# %%
id(l)
# Out:
# 140466430231168

# %%
result = l.pop()

# %%
id(l)
# Out:
# 140466430231168

# %%
result
# Out:
# 4

# %%
l.pop(1)
# Out:
# 2

# %%
l
# Out:
# [1, 3]

# %%
l = [1, 2, 3]

# %%
del l[1]

# %%
l
# Out:
# [1, 3]

# %%
l = [1, 2, 3, 4]

# %%
id(l)
# Out:
# 140466430204160

# %%
l.insert(1, 'a')

# %%
l
# Out:
# [1, 'a', 2, 3, 4]

# %%
id(l)
# Out:
# 140466430204160

# %%
l = [1, 2, 3]

# %%
l2 = l[::-1]

# %%
id(l), id(l2)
# Out:
# (140466430112448, 140466915514432)

# %%
l
# Out:
# [1, 2, 3]

# %%
l.reverse()

# %%
l
# Out:
# [3, 2, 1]

# %%
id(l)
# Out:
# 140466430112448

# %%
l = [1, 2, 3, 4]

# %%
id(l)
# Out:
# 140466430213824

# %%
l2 = l[:]

# %%
id(l), id(l2)
# Out:
# (140466430213824, 140466915439488)

# %%
l3 = l.copy()

# %%
l3
# Out:
# [1, 2, 3, 4]

# %%
id(l), id(l3)
# Out:
# (140466430213824, 140466430073280)

# %%
l = [['a', 'b'], 'c', 'd']

# %%
id(l), id(l[0]), id(l[1])
# Out:
# (140466430148160, 140466430152832, 11796240)

# %%
l2 = l.copy()

# %%
id(l2)
# Out:
# 140466428644224

# %%
id(l2[0]), id(l2[1])
# Out:
# (140466430152832, 11796240)

# %%
l2
# Out:
# [['a', 'b'], 'c', 'd']
