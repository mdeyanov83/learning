# %% [markdown]
# ### Assignments in Mutable Sequences

# %%
l = [1, 2, 3, 4, 5]
print(id(l))
# Out:
# 140605831501696

# %%
l[0:3]
# Out:
# [1, 2, 3]

# %%
l[0:3] = 'python'

# %%
id(l), l
# Out:
# (140605831501696, ['p', 'y', 't', 'h', 'o', 'n', 4, 5])

# %%
l = [1, 2, 3, 4, 5]
id(l)
# Out:
# 140605832252224

# %%
l[2:5]
# Out:
# [3, 4, 5]

# %%
l[2:5] = []

# %%
id(l), l
# Out:
# (140605832252224, [1, 2])

# %%
l = [1, 2, 3, 4, 5]
id(l)
# Out:
# 140605831693824

# %%
l[2:5] = ''

# %%
id(l), l
# Out:
# (140605831693824, [1, 2])

# %%
l = [1, 2, 3, 4, 5]
id(l)
# Out:
# 140605831708096

# %%
l[2:2]
# Out:
# []

# %%
s = slice(2, 2)

# %%
l[s]
# Out:
# []

# %%
s.start, s.stop
# Out:
# (2, 2)

# %%
l[2:2] = ('a', 100, 500)

# %%
id(l), l
# Out:
# (140605831708096, [1, 2, 'a', 100, 500, 3, 4, 5])

# %%
t = (1, 2, 3, 4, 5)

# %%
t[0:3]
# Out:
# (1, 2, 3)

# %%
t[0:3] = ['a', 'b', 'c']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 t[0:3] = ['a', 'b', 'c']
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[0] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 t[0] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %%
l
# Out:
# [1, 2, 'a', 100, 500, 3, 4, 5]

# %%
l[0]
# Out:
# 1

# %%
l = [1, 2, 3, 4, 5]

# %%
id(l)
# Out:
# 140605346399872

# %%
l[0:3]
# Out:
# [1, 2, 3]

# %%
l[0:3] = {100, 'X', 'a'}

# %%
id(l), l
# Out:
# (140605346399872, ['a', 100, 'X', 4, 5])

# %% [markdown]
# ### Extended Slices
