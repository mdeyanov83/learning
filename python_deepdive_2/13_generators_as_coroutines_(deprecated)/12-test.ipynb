# %% [markdown]
# ### Sending Exceptions to Generators

# %%
def gen():
    try:
        while True:
            received = yield
            print(received)
    finally:
        print('exception must have happened')

# %%
g = gen()
next(g)

# %%
g.send('hello')
# Out:
# hello

# %%
g.throw(ValueError, 'custom message')
# Out:
# /tmp/ipykernel_805/3706910579.py:1: DeprecationWarning: the (type, exc, tb) signature of throw() is deprecated, use the single-arg signature instead.
#   g.throw(ValueError, 'custom message')
# exception must have happened
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 g.throw(ValueError, 'custom message')
#
# Cell In[1], line 4, in gen()
#       2 try:
#       3     while True:
# ----> 4         received = yield
#       5         print(received)
#       6 finally:
#
# ValueError: custom message

# %%
def gen():
    try:
        while True:
            received = yield
            print(received)
    except ValueError:
        print('received a value error...')
    finally:
        print('exception must have happened')

# %%
g = gen()
next(g)

# %%
g.send('hello')
# Out:
# hello

# %%
g.throw(ValueError, 'custom message')
# Out:
# received a value error...
# exception must have happened
# /tmp/ipykernel_805/3706910579.py:1: DeprecationWarning: the (type, exc, tb) signature of throw() is deprecated, use the single-arg signature instead.
#   g.throw(ValueError, 'custom message')
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 g.throw(ValueError, 'custom message')
#
# StopIteration:

# %%
from inspect import getgeneratorstate

# %%
def gen():
    while True:
        try:
            received = yield
            print(received)
        except ValueError as ex:
            print('Value Error received:', str(ex))

# %%
g = gen()

# %%
next(g)

# %%
g.send('hello')
# Out:
# hello

# %%
g.throw(ValueError, 'custom message')
# Out:
# Value Error received: custom message
# /tmp/ipykernel_805/3706910579.py:1: DeprecationWarning: the (type, exc, tb) signature of throw() is deprecated, use the single-arg signature instead.
#   g.throw(ValueError, 'custom message')

# %%
getgeneratorstate(g)
# Out:
# 'GEN_SUSPENDED'

# %%
g.send('python')
# Out:
# python

# %%
def gen():
    while True:
        received = yield
        print(received)

# %%
g = gen()
next(g)
g.send('hello')
# Out:
# hello

# %%
g.throw(ValueError,'custom message')
# Out:
# /tmp/ipykernel_805/2110392286.py:1: DeprecationWarning: the (type, exc, tb) signature of throw() is deprecated, use the single-arg signature instead.
#   g.throw(ValueError,'custom message')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 g.throw(ValueError,'custom message')
#
# Cell In[18], line 3, in gen()
#       1 def gen():
#       2     while True:
# ----> 3         received = yield
#       4         print(received)
#
# ValueError: custom message

# %%
getgeneratorstate(g)
# Out:
# 'GEN_CLOSED'

# %%
def gen():
    try:
        while True:
            received = yield
            print(received)
    except ValueError as ex:
        print('ValueError received', str(ex))
        return None

# %%
g = gen()
next(g)
g.send('hello')
# Out:
# hello

# %%
g.throw(ValueError, 'custom messge')
# Out:
# ValueError received custom messge
# /tmp/ipykernel_805/2538577301.py:1: DeprecationWarning: the (type, exc, tb) signature of throw() is deprecated, use the single-arg signature instead.
#   g.throw(ValueError, 'custom messge')
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 g.throw(ValueError, 'custom messge')
#
# StopIteration:

# %%
def gen():
    try:
        while True:
            received = yield
            print(received)
    except ValueError as ex:
        print('ValueError received...', str(ex))
        raise ZeroDivisionError('not really')

# %%
g = gen()
next(g)
g.send('hello')
# Out:
# hello

# %%
g.throw(ValueError, 'custom message')
# Out:
# ValueError received... custom message
# /tmp/ipykernel_805/3706910579.py:1: DeprecationWarning: the (type, exc, tb) signature of throw() is deprecated, use the single-arg signature instead.
#   g.throw(ValueError, 'custom message')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 4, in gen()
#       3 while True:
# ----> 4     received = yield
#       5     print(received)
#
# ValueError: custom message
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 g.throw(ValueError, 'custom message')
#
# Cell In[25], line 8, in gen()
#       6 except ValueError as ex:
#       7     print('ValueError received...', str(ex))
# ----> 8     raise ZeroDivisionError('not really')
#
# ZeroDivisionError: not really

# %%
class CommitException(Exception):
    pass

class RollbackException(Exception):
    pass

def write_to_db():
    print('opening database connection...')
    print('start a transaction')
    try:
        while True:
            try:
                data = yield
                print('writing data to the databse', data)
            except CommitException:
                print('committing trasaction')
                print('opening next transaction...')
            except RollbackException:
                print('aborting transaction...')
                print('opening next transaction...')
    finally:
        print('generator closing')
        print('aborting transaction...')
        print('closingn database connection...')

# %%
sql = write_to_db()

# %%
next(sql)
# Out:
# opening database connection...
# start a transaction

# %%
sql.send(100)
# Out:
# writing data to the databse 100

# %%
sql.throw(CommitException)
# Out:
# committing trasaction
# opening next transaction...

# %%
sql.send(200)
# Out:
# writing data to the databse 200

# %%
sql.throw(RollbackException)
# Out:
# aborting transaction...
# opening next transaction...

# %%
getgeneratorstate(sql)
# Out:
# 'GEN_SUSPENDED'

# %%
sql.close()
# Out:
# generator closing
# aborting transaction...
# closingn database connection...
