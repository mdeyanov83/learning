# %% [markdown]
# ### Sending data to Generators

# %%
def echo():
    while True:
        received = yield
        print('You said:', received)

# %%
e = echo()

# %%
from inspect import getgeneratorstate

# %%
getgeneratorstate(e)
# Out:
# 'GEN_CREATED'

# %%
next(e)

# %%
getgeneratorstate(e)
# Out:
# 'GEN_SUSPENDED'
