# %% [markdown]
# ### Zipping

# %%
l1 = [1, 2, 3, 4, 5]
l2 = [1, 2, 3, 4]
l3 = [1, 2, 3]

# %%
results = zip(l1, l2, l3)

# %%
iter(results) is results
# Out:
# True

# %%
'__next__' in dir(results)
# Out:
# True

# %%
list(results)
# Out:
# [(1, 1, 1), (2, 2, 2), (3, 3, 3)]
