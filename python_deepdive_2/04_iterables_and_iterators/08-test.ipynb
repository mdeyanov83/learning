# %% [markdown]
# ### Consuming Iterators Manually

# %%
s = 'I sleep all night, and I work all day'

# %%
iter_s = iter(s)

# %%
next(iter_s)
# Out:
# 'I'

# %%
iter_s.__next__()
# Out:
# ' '

# %%
next(iter_s)
# Out:
# 's'
