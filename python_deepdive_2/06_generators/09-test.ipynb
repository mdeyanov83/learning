# %% [markdown]
# ### Generator Expressions

# %%
l = [i**2 for i in range(5)]

# %%
l
# Out:
# [0, 1, 4, 9, 16]

# %%
g = (i**2 for i in range(5))

# %%
type(g)
# Out:
# generator

# %%
for item in g:
    print(item)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
list(g)
# Out:
# []

# %%
import dis
