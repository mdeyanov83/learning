# %% [markdown]
# ### Yielding and Generators

# %%
import math

# %%
class FactIter:
    def __init__(self, n):
        self.n = n
        self.i = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.i > self.n:
            raise StopIteration
        else:
            result = math.factorial(self.i)
            self.i += 1
            return result

# %%
fact_iter = FactIter(5)

# %%
list(fact_iter)
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
list(fact_iter)
# Out:
# []

# %%
next(fact_iter)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 next(fact_iter)
#
# Cell In[3], line 11, in FactIter.__next__(self)
#       9 def __next__(self):
#      10     if self.i > self.n:
# ---> 11         raise StopIteration
#      12     else:
#      13         result = math.factorial(self.i)
#
# StopIteration:

# %%
def fact():
    i = 0
