# %% [markdown]
# ### Python 3.6 - Underscores in Numeric Literals

# %%
from sys import version_info

# %%
1000000
# Out:
# 1000000

# %%
10_000_000
# Out:
# 10000000

# %%
0x_FF_FFFF
# Out:
# 16777215

# %%
0x_F_F_F_F_F_F
# Out:
# 16777215

# %%
1_0_0_0.54_32_1
# Out:
# 1000.54321

# %%
'{:_}'.format(100000000)
# Out:
# '100_000_000'

# %%
'{:_x}'.format(16777215)
# Out:
# 'ff_ffff'

# %%
int('FF_FFFF', 16)
# Out:
# 16777215

# %%
int('0b_1_0000_0000', 2)
# Out:
# 256
