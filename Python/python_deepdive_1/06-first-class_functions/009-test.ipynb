# %% [markdown]
# ### Function Introspection

# %%
# dummy code
i = 100

# TODO: Fix this function
# currently does nothing, but should do...
def my_func(a: "mandatory positional",
            b: "optional positional" = 1,
            c=2,
            *args: "add extra positional here",
            kw1,
            kw2=100,
            k3=200,
            **kwargs: "provide extra kw-only here") -> "does nothing":
    """This function does nothing, but does have various parameters
    and annotations.
    """
    i = 10
    j = 20
    a = i + j
    return a

# %%
my_func.__doc__
# Out:
# 'This function does nothing, but does have various parameters\n    and annotations.\n    '

# %%
my_func.__annotations__
# Out:
# {'a': 'mandatory positional',
#  'b': 'optional positional',
#  'args': 'add extra positional here',
#  'kwargs': 'provide extra kw-only here',
#  'return': 'does nothing'}

# %%
my_func.short_description = "This is a function that does nothing much"

# %%
my_func.short_description
# Out:
# 'This is a function that does nothing much'

# %%
dir(my_func)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__',
#  'short_description']

# %%
my_func.__name__
# Out:
# 'my_func'

# %%
id(my_func)
# Out:
# 140484192214912

# %%
def func_call(f):
    print(id(f))
    print(f.__name__)

# %%
func_call(my_func)
# Out:
# 140484192214912
# my_func

# %%
my_func.__defaults__
# Out:
# (1, 2)

# %%
my_func.__kwdefaults__
# Out:
# {'kw2': 100, 'k3': 200}

# %%
my_func.__code__
# Out:
# <code object my_func at 0x7fc505876c10, file "/tmp/ipykernel_25105/3960533576.py", line 1>

# %%
dir(my_func.__code__)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_co_code_adaptive',
#  '_varname_from_oparg',
#  'co_argcount',
#  'co_cellvars',
#  'co_code',
#  'co_consts',
#  'co_exceptiontable',
#  'co_filename',
#  'co_firstlineno',
#  'co_flags',
#  'co_freevars',
#  'co_kwonlyargcount',
#  'co_lines',
#  'co_linetable',
#  'co_lnotab',
#  'co_name',
#  'co_names',
#  'co_nlocals',
#  'co_positions',
#  'co_posonlyargcount',
#  'co_qualname',
#  'co_stacksize',
#  'co_varnames',
#  'replace']

# %%
my_func.__code__.co_name
# Out:
# 'my_func'

# %%
my_func.__code__.co_varnames
# Out:
# ('a', 'b', 'c', 'kw1', 'kw2', 'k3', 'args', 'kwargs', 'i', 'j')

# %%
my_func.__code__.co_argcount
# Out:
# 3

# %%
import inspect

# %%
from inspect import isfunction, ismethod, isroutine

# %%
a = 10

# %%
isfunction(a)
# Out:
# False

# %%
isfunction(my_func)
# Out:
# True

# %%
ismethod(my_func)
# Out:
# False

# %%
class MyClass:
    def f(self):
        pass

# %%
isfunction(MyClass.f)
# Out:
# True

# %%
my_obj = MyClass()

# %%
isfunction(my_obj.f)
# Out:
# False

# %%
ismethod(my_obj.f)
# Out:
# True

# %%
isroutine(my_obj.f)
# Out:
# True

# %%
isroutine(MyClass.f)
# Out:
# True

# %%
print(inspect.getsource(my_func))
# Out:
# def my_func(a: "mandatory positional",
#             b: "optional positional" = 1,
#             c=2,
#             *args: "add extra positional here",
#             kw1,
#             kw2=100,
#             k3=200,
#             **kwargs: "provide extra kw-only here") -> "does nothing":
#     """This function does nothing, but does have various parameters
#     and annotations.
#     """
#     i = 10
#     j = 20
#     a = i + j
#     return a

# %%
inspect.getmodule(my_func)
# Out:
# <module '__main__'>

# %%
inspect.getmodule(print)
# Out:
# <module 'builtins' (built-in)>

# %%
import math

# %%
inspect.getmodule(math.sin)
# Out:
# <module 'math' (built-in)>

# %%
inspect.getcomments(my_func)
# Out:
# '# TODO: Fix this function\n# currently does nothing, but should do...\n'

# %%
my_func.__doc__
# Out:
# 'This function does nothing, but does have various parameters\n    and annotations.\n    '

# %%
inspect.signature(my_func)
# Out:
# <Signature (a: 'mandatory positional', b: 'optional positional' = 1, c=2, *args: 'add extra positional here', kw1, kw2=100, k3=200, **kwargs: 'provide extra kw-only here') -> 'does nothing'>

# %%
dir(inspect.signature(my_func))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_bind',
#  '_bound_arguments_cls',
#  '_hash_basis',
#  '_parameter_cls',
#  '_parameters',
#  '_return_annotation',
#  'bind',
#  'bind_partial',
#  'empty',
#  'from_callable',
#  'parameters',
#  'replace',
#  'return_annotation']

# %%
my_func.__annotations__
# Out:
# {'a': 'mandatory positional',
#  'b': 'optional positional',
#  'args': 'add extra positional here',
#  'kwargs': 'provide extra kw-only here',
#  'return': 'does nothing'}

# %%
inspect.signature(my_func).return_annotation
# Out:
# 'does nothing'

# %%
sig = inspect.signature(my_func)

# %%
sig
# Out:
# <Signature (a: 'mandatory positional', b: 'optional positional' = 1, c=2, *args: 'add extra positional here', kw1, kw2=100, k3=200, **kwargs: 'provide extra kw-only here') -> 'does nothing'>

# %%
sig.parameters
# Out:
# mappingproxy({'a': <Parameter "a: 'mandatory positional'">,
#               'b': <Parameter "b: 'optional positional' = 1">,
#               'c': <Parameter "c=2">,
#               'args': <Parameter "*args: 'add extra positional here'">,
#               'kw1': <Parameter "kw1">,
#               'kw2': <Parameter "kw2=100">,
#               'k3': <Parameter "k3=200">,
#               'kwargs': <Parameter "**kwargs: 'provide extra kw-only here'">})

# %%
for param in sig.parameters.values():
    print('Name: ', param.name)
    print('Default: ', param.default)
    print('Annotation: ', param.annotation)
    print('Kind: ', param.kind)
    print('-----------------------------')
# Out:
# Name:  a
# Default:  <class 'inspect._empty'>
# Annotation:  mandatory positional
# Kind:  POSITIONAL_OR_KEYWORD
# -----------------------------
# Name:  b
# Default:  1
# Annotation:  optional positional
# Kind:  POSITIONAL_OR_KEYWORD
# -----------------------------
# Name:  c
# Default:  2
# Annotation:  <class 'inspect._empty'>
# Kind:  POSITIONAL_OR_KEYWORD
# -----------------------------
# Name:  args
# Default:  <class 'inspect._empty'>
# Annotation:  add extra positional here
# Kind:  VAR_POSITIONAL
# -----------------------------
# Name:  kw1
# Default:  <class 'inspect._empty'>
# Annotation:  <class 'inspect._empty'>
# Kind:  KEYWORD_ONLY
# -----------------------------
# Name:  kw2
# Default:  100
# Annotation:  <class 'inspect._empty'>
# Kind:  KEYWORD_ONLY
# -----------------------------
# Name:  k3
# Default:  200
# Annotation:  <class 'inspect._empty'>
# Kind:  KEYWORD_ONLY
# -----------------------------
# Name:  kwargs
# Default:  <class 'inspect._empty'>
# Annotation:  provide extra kw-only here
# Kind:  VAR_KEYWORD
# -----------------------------

# %%
help(divmod)
# Out:
# Help on built-in function divmod in module builtins:
#
# divmod(x, y, /)
#     Return the tuple (x//y, x%y).  Invariant: div*y + mod == x.

# %%
divmod(2, 3)
# Out:
# (0, 2)

# %%
divmod(x=2, y=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 divmod(x=2, y=3)
#
# TypeError: divmod() takes no keyword arguments

# %%
for param in inspect.signature(divmod).parameters.values():
    print(param.kind)
# Out:
# POSITIONAL_ONLY
# POSITIONAL_ONLY

# %%
def test_func(a, b, /):
    print(a+b)

# %%
test_func(1, 2)
# Out:
# 3

# %%
test_func(a=1, b=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 test_func(a=1, b=2)
#
# TypeError: test_func() got some positional-only arguments passed as keyword arguments: 'a, b'
