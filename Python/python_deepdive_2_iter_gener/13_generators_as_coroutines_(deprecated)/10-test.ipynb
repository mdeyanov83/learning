# %% [markdown]
# ### Closing Generators

# %%
from inspect import getgeneratorstate

# %%
import csv

def parse_file(f_name):
    print('opening file...')
    f = open(f_name, 'r')
    try:
        dialect = csv.Sniffer().sniff(f.read(2000))
        f.seek(0)
        reader = csv.reader(f,dialect=dialect)
        for row in reader:
            yield row
    finally:
        print('closing file...')
        f.close()

# %%
import itertools

parser = parse_file('cars.csv')
for row in itertools.islice(parser, 10):
    print(row)
# Out:
# opening file...
# ['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model', 'Origin']
# ['Chevrolet Chevelle Malibu', '18.0', '8', '307.0', '130.0', '3504.', '12.0', '70', 'US']
# ['Buick Skylark 320', '15.0', '8', '350.0', '165.0', '3693.', '11.5', '70', 'US']
# ['Plymouth Satellite', '18.0', '8', '318.0', '150.0', '3436.', '11.0', '70', 'US']
# ['AMC Rebel SST', '16.0', '8', '304.0', '150.0', '3433.', '12.0', '70', 'US']
# ['Ford Torino', '17.0', '8', '302.0', '140.0', '3449.', '10.5', '70', 'US']
# ['Ford Galaxie 500', '15.0', '8', '429.0', '198.0', '4341.', '10.0', '70', 'US']
# ['Chevrolet Impala', '14.0', '8', '454.0', '220.0', '4354.', '9.0', '70', 'US']
# ['Plymouth Fury iii', '14.0', '8', '440.0', '215.0', '4312.', '8.5', '70', 'US']
# ['Pontiac Catalina', '14.0', '8', '455.0', '225.0', '4425.', '10.0', '70', 'US']

# %%
parser.close()
# Out:
# closing file...

# %%
def parse_file(f_name):
    print('opening file...')
    f = open(f_name, 'r')
    try:
        dialect = csv.Sniffer().sniff(f.read(2000))
        f.seek(0)
        reader = csv.reader(f,dialect=dialect)
        for row in reader:
            yield row
    except Exception as ex:
        print('some exception occurred', str(ex))
    except GeneratorExit:
        print('generator was closed')
    finally:
        print('closing file...')
        f.close()

# %%
parser = parse_file('cars.csv')
for row in itertools.islice(parser, 10):
    print(row)
# Out:
# opening file...
# ['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model', 'Origin']
# ['Chevrolet Chevelle Malibu', '18.0', '8', '307.0', '130.0', '3504.', '12.0', '70', 'US']
# ['Buick Skylark 320', '15.0', '8', '350.0', '165.0', '3693.', '11.5', '70', 'US']
# ['Plymouth Satellite', '18.0', '8', '318.0', '150.0', '3436.', '11.0', '70', 'US']
# ['AMC Rebel SST', '16.0', '8', '304.0', '150.0', '3433.', '12.0', '70', 'US']
# ['Ford Torino', '17.0', '8', '302.0', '140.0', '3449.', '10.5', '70', 'US']
# ['Ford Galaxie 500', '15.0', '8', '429.0', '198.0', '4341.', '10.0', '70', 'US']
# ['Chevrolet Impala', '14.0', '8', '454.0', '220.0', '4354.', '9.0', '70', 'US']
# ['Plymouth Fury iii', '14.0', '8', '440.0', '215.0', '4312.', '8.5', '70', 'US']
# ['Pontiac Catalina', '14.0', '8', '455.0', '225.0', '4425.', '10.0', '70', 'US']

# %%
parser.close()
# Out:
# generator was closed
# closing file...

# %%
def parse_file(f_name):
    print('opening file...')
    f = open(f_name, 'r')
    try:
        dialect = csv.Sniffer().sniff(f.read(2000))
        f.seek(0)
        next(f)  # skip header row
        reader = csv.reader(f,dialect=dialect)
        for row in reader:
            try:
                yield row
            except GeneratorExit:
                print('ignoring call to close generator...')
    finally:
        print('closing file...')
        f.close()

# %%
parser = parse_file('cars.csv')
for row in itertools.islice(parser, 10):
    print(row)
# Out:
# opening file...
# ['Chevrolet Chevelle Malibu', '18.0', '8', '307.0', '130.0', '3504.', '12.0', '70', 'US']
# ['Buick Skylark 320', '15.0', '8', '350.0', '165.0', '3693.', '11.5', '70', 'US']
# ['Plymouth Satellite', '18.0', '8', '318.0', '150.0', '3436.', '11.0', '70', 'US']
# ['AMC Rebel SST', '16.0', '8', '304.0', '150.0', '3433.', '12.0', '70', 'US']
# ['Ford Torino', '17.0', '8', '302.0', '140.0', '3449.', '10.5', '70', 'US']
# ['Ford Galaxie 500', '15.0', '8', '429.0', '198.0', '4341.', '10.0', '70', 'US']
# ['Chevrolet Impala', '14.0', '8', '454.0', '220.0', '4354.', '9.0', '70', 'US']
# ['Plymouth Fury iii', '14.0', '8', '440.0', '215.0', '4312.', '8.5', '70', 'US']
# ['Pontiac Catalina', '14.0', '8', '455.0', '225.0', '4425.', '10.0', '70', 'US']
# ['AMC Ambassador DPL', '15.0', '8', '390.0', '190.0', '3850.', '8.5', '70', 'US']

# %%
parser.close()
# Out:
# ignoring call to close generator...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 parser.close()
#
# RuntimeError: generator ignored GeneratorExit

# %%
def parse_file(f_name):
    print('opening file...')
    f = open(f_name, 'r')
    try:
        dialect = csv.Sniffer().sniff(f.read(2000))
        f.seek(0)
        next(f)  # skip header row
        reader = csv.reader(f,dialect=dialect)
        for row in reader:
            try:
                yield row
            except GeneratorExit:
                print('got call to close generaitor...')
                raise
    finally:
        print('closing file...')
        f.close()

# %%
parser = parse_file('cars.csv')
for row in itertools.islice(parser, 10):
    print(row)
# Out:
# opening file...
# ['Chevrolet Chevelle Malibu', '18.0', '8', '307.0', '130.0', '3504.', '12.0', '70', 'US']
# ['Buick Skylark 320', '15.0', '8', '350.0', '165.0', '3693.', '11.5', '70', 'US']
# ['Plymouth Satellite', '18.0', '8', '318.0', '150.0', '3436.', '11.0', '70', 'US']
# ['AMC Rebel SST', '16.0', '8', '304.0', '150.0', '3433.', '12.0', '70', 'US']
# ['Ford Torino', '17.0', '8', '302.0', '140.0', '3449.', '10.5', '70', 'US']
# ['Ford Galaxie 500', '15.0', '8', '429.0', '198.0', '4341.', '10.0', '70', 'US']
# ['Chevrolet Impala', '14.0', '8', '454.0', '220.0', '4354.', '9.0', '70', 'US']
# ['Plymouth Fury iii', '14.0', '8', '440.0', '215.0', '4312.', '8.5', '70', 'US']
# ['Pontiac Catalina', '14.0', '8', '455.0', '225.0', '4425.', '10.0', '70', 'US']
# ['AMC Ambassador DPL', '15.0', '8', '390.0', '190.0', '3850.', '8.5', '70', 'US']

# %%
parser.close()
# Out:
# got call to clsoe generaitor...
# closing file...

# %%
def parse_file(f_name):
    print('opening file...')
    f = open(f_name, 'r')
    try:
        dialect = csv.Sniffer().sniff(f.read(2000))
        f.seek(0)
        next(f)  # skip header row
        reader = csv.reader(f,dialect=dialect)
        for row in reader:
            try:
                yield row
            except GeneratorExit:
                print('got call to close generaitor...')
                return
    finally:
        print('closing file...')
        f.close()

# %%
parser = parse_file('cars.csv')
for row in itertools.islice(parser, 5):
    print(row)
# Out:
# opening file...
# ['Chevrolet Chevelle Malibu', '18.0', '8', '307.0', '130.0', '3504.', '12.0', '70', 'US']
# ['Buick Skylark 320', '15.0', '8', '350.0', '165.0', '3693.', '11.5', '70', 'US']
# ['Plymouth Satellite', '18.0', '8', '318.0', '150.0', '3436.', '11.0', '70', 'US']
# ['AMC Rebel SST', '16.0', '8', '304.0', '150.0', '3433.', '12.0', '70', 'US']
# ['Ford Torino', '17.0', '8', '302.0', '140.0', '3449.', '10.5', '70', 'US']

# %%
parser.close()
# Out:
# got call to close generaitor...
# closing file...

# %%
def parse_file(f_name):
    print('opening file...')
    f = open(f_name, 'r')
    try:
        dialect = csv.Sniffer().sniff(f.read(2000))
        f.seek(0)
        next(f)  # skip header row
        reader = csv.reader(f,dialect=dialect)
        for row in reader:
            try:
                yield row
            except GeneratorExit:
                print('got call to close generaitor...')
                raise Exception('Why, oh why did you do this') from None
    finally:
        print('closing file...')
        f.close()

# %%
parser = parse_file('cars.csv')
for row in itertools.islice(parser, 5):
    print(row)
# Out:
# opening file...
# ['Chevrolet Chevelle Malibu', '18.0', '8', '307.0', '130.0', '3504.', '12.0', '70', 'US']
# ['Buick Skylark 320', '15.0', '8', '350.0', '165.0', '3693.', '11.5', '70', 'US']
# ['Plymouth Satellite', '18.0', '8', '318.0', '150.0', '3436.', '11.0', '70', 'US']
# ['AMC Rebel SST', '16.0', '8', '304.0', '150.0', '3433.', '12.0', '70', 'US']
# ['Ford Torino', '17.0', '8', '302.0', '140.0', '3449.', '10.5', '70', 'US']

# %%
parser.close()
# Out:
# got call to close generaitor...
# closing file...
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 parser.close()
#
# Cell In[34], line 14, in parse_file(f_name)
#      12         except GeneratorExit:
#      13             print('got call to close generaitor...')
# ---> 14             raise Exception('Why, oh why did you do this') from None
#      15 finally:
#      16     print('closing file...')
#
# Exception: Why, oh why did you do this

# %%
def save_to_db():
    print('starting new transaction')
    while True:
        try:
            data = yield
            print('sending data to database:', str(data))
        except GeneratorExit:
            print('commiting transaction')
            raise

# %%
trans = save_to_db()

# %%
next(trans)
# Out:
# starting new transaction

# %%
trans.send('data 1')
# Out:
# sending data to database: data 1

# %%
trans.send('data 2')
# Out:
# sending data to database: data 2

# %%
trans.close()
# Out:
# commiting transaction

# %%
def save_to_db():
    print('starting new transaction')
    while True:
        try:
            data = yield
            print('sending data to database:', eval(data))
        except Exception:
            print('aborting the transaction')
        except GeneratorExit:
            print('commiting transaction')
            raise

# %%
trans = save_to_db()
# Out:
# commiting transaction

# %%
next(trans)
# Out:
# starting new transaction

# %%
trans.send('1 + 10')
# Out:
# sending data to database: 11

# %%
trans.send('1/0')
# Out:
# aborting the transaction

# %%
from inspect import getgeneratorstate

# %%
getgeneratorstate(trans)
# Out:
# 'GEN_SUSPENDED'

# %%
trans = save_to_db()
# Out:
# commiting transaction

# %%
next(trans)
# Out:
# starting new transaction

# %%
trans.send('1 + 10')
# Out:
# sending data to database: 11

# %%
trans.close()
# Out:
# commiting transaction

# %%
getgeneratorstate(trans)
# Out:
# 'GEN_CLOSED'

# %%
def save_to_db():
    print('starting new transaction')
    is_abort = False
    try:
        while True:
            data = yield
            print('sending data to database:', eval(data))
    except Exception:
        is_abort = True
        raise
    finally:
        if is_abort:
            print('rollback transaction')
        else:
            print('commit transaction')

# %%
trans = save_to_db()
next(trans)
trans.send('1+1')
trans.close()
# Out:
# starting new transaction
# sending data to database: 2
# commit transaction

# %%
trans = save_to_db()
next(trans)
trans.send('1/0')
trans.close()
# Out:
# starting new transaction
# rollback transaction
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[66], line 3
#       1 trans = save_to_db()
#       2 next(trans)
# ----> 3 trans.send('1/0')
#       4 trans.close()
#
# Cell In[64], line 7, in save_to_db()
#       5     while True:
#       6         data = yield
# ----> 7         print('sending data to database:', eval(data))
#       8 except Exception:
#       9     is_abort = True
#
# File <string>:1
#
# ZeroDivisionError: division by zero

# %%
class TransactionAborted(Exception):
    pass

def save_to_db():
    print('starting new transaction')
    is_abort = False
    try:
        while True:
            data = yield
            print('sending data to database:', eval(data))
    except Exception as e:
        is_abort = True
        raise TransactionAborted(str(e))
    finally:
        if is_abort:
            print('rollback transaction')
        else:
            print('commit transaction')

# %%
trans = save_to_db()
next(trans)
trans.send('1/0')
trans.close()
# Out:
# starting new transaction
# rollback transaction
# ---------------------------------------------------------------------------
# TransactionAborted                        Traceback (most recent call last)
# Cell In[72], line 3
#       1 trans = save_to_db()
#       2 next(trans)
# ----> 3 trans.send('1/0')
#       4 trans.close()
#
# Cell In[71], line 13, in save_to_db()
#      11 except Exception as e:
#      12     is_abort = True
# ---> 13     raise TransactionAborted(str(e)) from None
#      14 finally:
#      15     if is_abort:
#
# TransactionAborted: division by zero
