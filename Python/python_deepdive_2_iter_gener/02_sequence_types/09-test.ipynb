# %% [markdown]
# ### Copying Sequences

# %%
l1 = [1, 2, 3]

l1_copy = []
for item in l1:
    l1_copy.append(item)

print(l1_copy)
print(id(l1), id(l1_copy))
# Out:
# [1, 2, 3]
# 140700243778368 140700243726592

# %%
l1_copy = [item for item in l1]

# %%
l1_copy
# Out:
# [1, 2, 3]

# %%
id(l1), id(l1_copy)
# Out:
# (140700243778368, 140700243786624)

# %%
l1_copy = l1.copy()

# %%
l1_copy
# Out:
# [1, 2, 3]

# %%
id(l1_copy), id(l1)
# Out:
# (140700243887168, 140700243778368)

# %%
l1_copy = list(l1)

# %%
t1 = (1, 2, 3)

# %%
l1_copy = list(t1)

# %%
l1_copy
# Out:
# [1, 2, 3]

# %%
t1 = (1, 2, 3)

# %%
t2 = tuple(t1)

# %%
id(t1), id(t2)
# Out:
# (140700244625472, 140700244625472)

# %%
t1 is t2
# Out:
# True

# %%
t1 = (1, 2, 3)
t2 = t1[:]

# %%
t1 is t2
# Out:
# True

# %%
s1 = 'python'
s2 = str(s1)
s3 = s1[:]

# %%
s1 is s2, s1 is s3
# Out:
# (True, True)

# %%
import copy

# %%
l1 = [1, 2, 3]

# %%
l2 = copy.copy(l1)

# %%
l1 is l2
# Out:
# False

# %%
t1 = (1, 2, 3)

# %%
t2 = copy.copy(t1)

# %%
t1 is t2
# Out:
# True

# %% [markdown]
# ### Deep Copies

# %%
v1 = [0, 0]
v2 = [0, 0]

line1 = [v1, v2]

# %%
line2 = line1.copy()

# %%
id(line1), id(line2)
# Out:
# (140700244867136, 140700244859392)

# %%
id(line1[0]), id(line2[0])
# Out:
# (140700244882432, 140700244882432)

# %%
line2 = [v for v in line1]

# %%
id(line1), id(line2)
# Out:
# (140700244867136, 140700244895424)

# %%
id(line1[0]), id(line2[0])
# Out:
# (140700244882432, 140700244882432)

# %%
print(line1)
print(line2)
# Out:
# [[0, 0], [0, 0]]
# [[0, 0], [0, 0]]

# %%
line1[0][0] = 100

# %%
line1
# Out:
# [[100, 0], [0, 0]]

# %%
line2
# Out:
# [[100, 0], [0, 0]]

# %%
line2 = [v.copy() for v in line1]

# %%
id(line1), id(line2)
# Out:
# (140700244867136, 140700243786048)

# %%
id(line1[0]), id(line2[0])
# Out:
# (140700244882432, 140700244891264)

# %%
line1[0][0] = -10

# %%
line1
# Out:
# [[-10, 0], [0, 0]]

# %%
line2
# Out:
# [[100, 0], [0, 0]]

# %%
v1 = [1, 1]
v2 = [2, 2]
v3 = [3, 3]
v4 = [4, 4]

line1 = [v1, v2]
line2 = [v3, v4]

plane1 = [line1, line2]

# %%
plane2 = [line.copy() for line in plane1]

# %%
print(plane1)
print(plane2)
# Out:
# [[[1, 1], [2, 2]], [[3, 3], [4, 4]]]
# [[[1, 1], [2, 2]], [[3, 3], [4, 4]]]

# %%
id(plane1[0]), id(plane2[0])
# Out:
# (140699881586368, 140700244892800)

# %%
print(plane1[0])
print(plane2[0])
# Out:
# [[1, 1], [2, 2]]
# [[1, 1], [2, 2]]

# %%
id(plane1[0][0]), id(plane2[0][0])
# Out:
# (140699881571520, 140699881571520)

# %%
v1 = [1, 1]
v2 = [2, 2]
v3 = [3, 3]
v4 = [4, 4]

line1 = [v1, v2]
line2 = [v3, v4]

plane1 = [line1, line2]

# %%
plane2 = copy.deepcopy(plane1)

# %%
id(plane1), id(plane2)
# Out:
# (140699881576960, 140699882176768)

# %%
id(plane1[0]), id(plane2[0])
# Out:
# (140700244869760, 140699882014528)

# %%
id(plane1[0][0]), id(plane2[0][0])
# Out:
# (140699882016832, 140700243717888)

# %%
plane1[0][0][0] = 100

# %%
print(plane1)
print(plane2)
# Out:
# [[[100, 1], [2, 2]], [[3, 3], [4, 4]]]
# [[[1, 1], [2, 2]], [[3, 3], [4, 4]]]

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __repr__(self):
        return f'Point({self.x}, {self.y})'

# %%
class Line:
    def __init__(self, p1, p2):
        self.p1 = p1
        self.p2 = p2

    def __repr__(self):
        return f'Line({self.p1.__repr__()}, {self.p2.__repr__()})'

# %%
p1 = Point(0, 0)
p2 = Point(10, 10)
line1 = Line(p1, p2)
line2 = copy.deepcopy(line1)

# %%
print(line1.p1, id(line1.p1))
print(line2.p1, id(line2.p1))
# Out:
# Point(0, 0) 140699880246112
# Point(0, 0) 140699880257920

# %%
p1 = Point(0, 0)
p2 = Point(10, 10)
line1 = Line(p1, p2)
line2 = copy.copy(line1)

# %%
print(line1.p1, id(line1.p1))
print(line2.p1, id(line2.p1))
# Out:
# Point(0, 0) 140699880247984
# Point(0, 0) 140699880247984
