# %% [markdown]
# #### Timing code using timeit

# %%
from timeit import timeit

# %%
help(timeit)
# Out:
# Help on function timeit in module timeit:
#
# timeit(stmt='pass', setup='pass', timer=<built-in function perf_counter>, number=1000000, globals=None)
#     Convenience function to create Timer object and call timeit method.

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'from timeit import timeit',
#   'help(timeit0)',
#   'help(timeit)',
#   'globals()'],
#  '_oh': {},
#  '_dh': [PosixPath('/workspaces/LocalDev/learning/python_deepdive1/11-extras')],
#  'In': ['',
#   'from timeit import timeit',
#   'help(timeit0)',
#   'help(timeit)',
#   'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f11c5c5a420>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f11bc6d5ee0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f11bc6d5ee0>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/LocalDev/learning/python_deepdive1/11-extras/006-test.ipynb',
#  '_i': 'help(timeit)',
#  '_ii': 'help(timeit0)',
#  '_iii': 'from timeit import timeit',
#  '_i1': 'from timeit import timeit',
#  'timeit': <function timeit.timeit(stmt='pass', setup='pass', timer=<built-in function perf_counter>, number=1000000, globals=None)>,
#  '_i2': 'help(timeit0)',
#  '_i3': 'help(timeit)',
#  '_i4': 'globals()'}

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'from timeit import timeit',
#   'help(timeit0)',
#   'help(timeit)',
#   'globals()',
#   'locals()'],
#  '_oh': {4: {...}},
#  '_dh': [PosixPath('/workspaces/LocalDev/learning/python_deepdive1/11-extras')],
#  'In': ['',
#   'from timeit import timeit',
#   'help(timeit0)',
#   'help(timeit)',
#   'globals()',
#   'locals()'],
#  'Out': {4: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f11c5c5a420>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f11bc6d5ee0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f11bc6d5ee0>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/LocalDev/learning/python_deepdive1/11-extras/006-test.ipynb',
#  '_i': 'globals()',
#  '_ii': 'help(timeit)',
#  '_iii': 'help(timeit0)',
#  '_i1': 'from timeit import timeit',
#  'timeit': <function timeit.timeit(stmt='pass', setup='pass', timer=<built-in function perf_counter>, number=1000000, globals=None)>,
#  '_i2': 'help(timeit0)',
#  '_i3': 'help(timeit)',
#  '_i4': 'globals()',
#  '_4': {...},
#  '_i5': 'locals()'}

# %%
import math
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
from math import sqrt
sqrt(2)
# Out:
# 1.4142135623730951

# %%
timeit(stmt='import math\nmath.sqrt(2)')
# Out:
# 0.33263487400108716

# %%
timeit(stmt='math.sqrt(2)', setup='import math')
# Out:
# 0.13662397399821202

# %%
timeit(stmt='sqrt(2)', setup='from math import sqrt')
# Out:
# 0.14860165400023106

# %%
'math' in globals()
# Out:
# True

# %%
timeit(stmt='math.sqrt(2)', globals=globals())
# Out:
# 0.12213812900154153

# %%
import random

# %%
l = random.choices(list('python'), k=500)

# %%
'l' in globals()
# Out:
# True

# %%
timeit(stmt='random.choice(l)', setup='import random')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 timeit(stmt='random.choice(l)', setup='import random')
#
# File /usr/lib/python3.12/timeit.py:237, in timeit(stmt, setup, timer, number, globals)
#     234 def timeit(stmt="pass", setup="pass", timer=default_timer,
#     235            number=default_number, globals=None):
#     236     """Convenience function to create Timer object and call timeit method."""
# --> 237     return Timer(stmt, setup, timer, globals).timeit(number)
#
# File /usr/lib/python3.12/timeit.py:180, in Timer.timeit(self, number)
#     178 gc.disable()
#     179 try:
# --> 180     timing = self.inner(it, self.timer)
#     181 finally:
#     182     if gcold:
#
# File <timeit-src>:6, in inner(_it, _timer)
#
# NameError: name 'l' is not defined

# %%
timeit(stmt='random.choice(l)', setup='import random', globals=globals())
# Out:
# 1.0758459200005746

# %%
def pick_random():
    randoms = random.choices(list('python'), k=500)
    return timeit(stmt='random.choice(randoms)',
           setup='import random',
           globals=locals())

# %%
'randoms' in globals()
# Out:
# False

# %%
pick_random()
# Out:
# 0.6128562060002878

# %%
def pick_random(lst):
    return random.choice(lst)

# %%
timeit(stmt='pick_random(l)', globals=globals())
# Out:
# 1.155989459999546

# %%
'pick_random' in globals()
# Out:
# True

# %%
'l' in globals()
# Out:
# True

# %%
timeit(stmt='pick_random(l)', globals=globals())
# Out:
# 0.9152405119966716
