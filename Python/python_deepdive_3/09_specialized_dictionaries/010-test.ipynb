# %% [markdown]
# ### ChainMap

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}
d3 = {'e': 5, 'f': 6}

# %%
d = {**d1, **d2, **d3}

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
d = {}
d.update(d1)
d.update(d2)
d.update(d3)

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
from collections import ChainMap

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}
d3 = {'e': 5, 'f': 6}

# %%
d = ChainMap(d1, d2, d3)

# %%
print(d)
# Out:
# ChainMap({'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})

# %%
isinstance(d, dict)
# Out:
# False

# %%
d['a']
# Out:
# 1

# %%
d['f']
# Out:
# 6

# %%
for k, v in d.items():
    print(k, v)
# Out:
# e 5
# f 6
# c 3
# d 4
# a 1
# b 2

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'b': 20, 'c': 3}
d3 = {'c': 30, 'd': 4}

# %%
d = {**d1, **d2, **d3}

# %%
d
# Out:
# {'a': 1, 'b': 20, 'c': 30, 'd': 4}

# %%
d = ChainMap(d1, d2, d3)

# %%
d['b']
# Out:
# 2

# %%
d
# Out:
# ChainMap({'a': 1, 'b': 2}, {'b': 20, 'c': 3}, {'c': 30, 'd': 4})

# %%
for k, v in d.items():
    print(k, v)
# Out:
# c 3
# d 4
# b 2
# a 1

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}
d3 = {'e': 5, 'f': 6}
d = ChainMap(d1, d2, d3)

# %%
d['z'] = 100

# %%
print(d)
# Out:
# ChainMap({'a': 1, 'b': 2, 'z': 100}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})

# %%
for key in d:
    print(key)
# Out:
# e
# f
# c
# d
# a
# b
# z

# %%
d1
# Out:
# {'a': 1, 'b': 2, 'z': 100}

# %%
d['c'] = 300

# %%
d['c']
# Out:
# 300

# %%
d
# Out:
# ChainMap({'a': 1, 'b': 2, 'z': 100, 'c': 300}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})

# %%
del d['e']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.12/collections/__init__.py:1071, in ChainMap.__delitem__(self, key)
#    1070 try:
# -> 1071     del self.maps[0][key]
#    1072 except KeyError:
#
# KeyError: 'e'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 del d['e']
#
# File /usr/lib/python3.12/collections/__init__.py:1073, in ChainMap.__delitem__(self, key)
#    1071     del self.maps[0][key]
#    1072 except KeyError:
# -> 1073     raise KeyError(f'Key not found in the first mapping: {key!r}')
#
# KeyError: "Key not found in the first mapping: 'e'"

# %%
del d['c']

# %%
d['c']
# Out:
# 3

# %%
d3['x'] = 500

# %%
d
# Out:
# ChainMap({'a': 1, 'b': 2, 'z': 100}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6, 'x': 500})

# %%
d['x']
# Out:
# 500

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}
d = ChainMap(d1, d2)
print(id(d))
# Out:
# 140153118671984

# %%
d3 = {'d': 400, 'e': 5}
d = ChainMap(d, d3)
print(id(d))
# Out:
# 140153118858112

# %%
d
# Out:
# ChainMap(ChainMap({'a': 1, 'b': 2}, {'c': 3, 'd': 4}), {'d': 400, 'e': 5})

# %%
d['d']
# Out:
# 4

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}
d = ChainMap(d1, d2)

# %%
d3 = {'d': 400, 'e': 5}
d = ChainMap(d3, d)

# %%
d
# Out:
# ChainMap({'d': 400, 'e': 5}, ChainMap({'a': 1, 'b': 2}, {'c': 3, 'd': 4}))

# %%
d['d']
# Out:
# 400

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}
d = ChainMap(d1, d2)

# %%
d3 = {'d': 400, 'e': 5}

# %%
d = d.new_child(d3)

# %%
d
# Out:
# ChainMap({'d': 400, 'e': 5}, {'a': 1, 'b': 2}, {'c': 3, 'd': 4})

# %%
d.parents
# Out:
# ChainMap({'a': 1, 'b': 2}, {'c': 3, 'd': 4})

# %%
type(d.maps), d.maps
# Out:
# (list, [{'d': 400, 'e': 5}, {'a': 1, 'b': 2}, {'c': 3, 'd': 4}])

# %%
d3 = {'e': 5, 'f': 6}

# %%
d
# Out:
# ChainMap({'d': 400, 'e': 5}, {'a': 1, 'b': 2}, {'c': 3, 'd': 4})

# %%
d.maps.append(d3)

# %%
d
# Out:
# ChainMap({'d': 400, 'e': 5}, {'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})

# %%
d['f']
# Out:
# 6

# %%
d.maps
# Out:
# [{'d': 400, 'e': 5}, {'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6}]

# %%
del d.maps[0]

# %%
d
# Out:
# ChainMap({'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})

# %%
d.maps
# Out:
# [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6}]

# %%
config = {
    'host': 'prod.deepdive.com',
    'port': 5432,
    'database': 'deepdive',
    'user_id': '$pg_user',
    'user_pwd': '$pg_pwd'
}

# %%
local_config = ChainMap({}, config)

# %%
list(local_config.items())
# Out:
# [('host', 'prod.deepdive.com'),
#  ('port', 5432),
#  ('database', 'deepdive'),
#  ('user_id', '$pg_user'),
#  ('user_pwd', '$pg_pwd')]

# %%
local_config['user_id'] = 'test'
local_config['user_pwd'] = 'test'

# %%
list(local_config.items())
# Out:
# [('host', 'prod.deepdive.com'),
#  ('port', 5432),
#  ('database', 'deepdive'),
#  ('user_id', 'test'),
#  ('user_pwd', 'test')]

# %%
local_config
# Out:
# ChainMap({'user_id': 'test', 'user_pwd': 'test'}, {'host': 'prod.deepdive.com', 'port': 5432, 'database': 'deepdive', 'user_id': '$pg_user', 'user_pwd': '$pg_pwd'})
