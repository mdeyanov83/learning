# %% [markdown]
# ### The `object` Class

# %%
type(object)
# Out:
# type

# %%
type(int), type(str), type(dict)
# Out:
# (type, type, type)

# %%
class Person:
    pass

# %%
issubclass(Person, object)
# Out:
# True

# %%
issubclass(int, object)
# Out:
# True

# %%
import math

# %%
type(math)
# Out:
# module

# %%
ty = type(math)

# %%
type(ty)
# Out:
# type

# %%
issubclass(ty, object)
# Out:
# True

# %%
import types

# %%
dir(types)
# Out:
# ['AsyncGeneratorType',
#  'BuiltinFunctionType',
#  'BuiltinMethodType',
#  'CellType',
#  'ClassMethodDescriptorType',
#  'CodeType',
#  'CoroutineType',
#  'DynamicClassAttribute',
#  'EllipsisType',
#  'FrameType',
#  'FunctionType',
#  'GeneratorType',
#  'GenericAlias',
#  'GetSetDescriptorType',
#  'LambdaType',
#  'MappingProxyType',
#  'MemberDescriptorType',
#  'MethodDescriptorType',
#  'MethodType',
#  'MethodWrapperType',
#  'ModuleType',
#  'NoneType',
#  'NotImplementedType',
#  'SimpleNamespace',
#  'TracebackType',
#  'UnionType',
#  'WrapperDescriptorType',
#  '_GeneratorWrapper',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_calculate_meta',
#  'coroutine',
#  'get_original_bases',
#  'new_class',
#  'prepare_class',
#  'resolve_bases']

# %%
def my_func():
    pass

# %%
type(my_func)
# Out:
# function

# %%
types.FunctionType is type(my_func)
# Out:
# True

# %%
types.ModuleType is type(math)
# Out:
# True

# %%
isinstance(my_func, object)
# Out:
# True

# %%
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
o1 = object()

# %%
str(o1), repr(o1)
# Out:
# ('<object object at 0x7f2b042a2e10>', '<object object at 0x7f2b042a2e10>')

# %%
class Person:
    pass

# %%
p = Person()

# %%
str(p), repr(p)
# Out:
# ('<__main__.Person object at 0x7f2b045c1f40>',
#  '<__main__.Person object at 0x7f2b045c1f40>')

# %%
o1 = object()
o2 = object()
id(o1), id(o2)
# Out:
# (139822730194080, 139822730194448)

# %%
o1, o2
# Out:
# (<object at 0x7f2b042a2ca0>, <object at 0x7f2b042a2e10>)

# %%
o1 is o2
# Out:
# False

# %%
o1 == o2
# Out:
# False

# %%
o1 is o1
# Out:
# True

# %%
o1 == o2
# Out:
# False

# %%
o3 = o1

# %%
o1 is o3, o1 == o3
# Out:
# (True, True)

# %%
p1 = Person()
p2 = Person()

# %%
p1 is p2, p1 == p2, p1 is p1, p1 == p1
# Out:
# (False, False, True, True)

# %%
id(Person.__eq__)
# Out:
# 139823082046224

# %%
id(object.__eq__)
# Out:
# 139823082046224

# %%
id(Person.__init__), id(object.__init__)
# Out:
# (139823082046544, 139823082046544)

# %%
class Person:
    def __init__(self):
        pass

# %%
id(Person.__init__), id(object.__init__)
# Out:
# (139822383310432, 139823082046544)

# %%
p = Person()
