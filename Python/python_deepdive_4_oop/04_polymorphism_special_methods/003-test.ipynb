# %% [markdown]
# ### `__str__` and `__repr__`

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        print('__repr__ called')
        return f"Person(name='{self.name}', age={self.age})"

# %%
p = Person('Python', 30)

# %%
p
# Out:
# __repr__ called
# Person(name='Python', age=30)

# %%
print(p)
# Out:
# __repr__ called
# Person(name='Python', age=30)

# %%
str(p)
# Out:
# __repr__ called
# "Person(name='Python', age=30)"

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        print('__repr__ called')
        return f"Person(name='{self.name}', age={self.age})"

    def __str__(self):
        print('__str__ called')
        return self.name

# %%
p = Person('Python', 30)

# %%
p
# Out:
# __repr__ called
# Person(name='Python', age=30)

# %%
print(p)
# Out:
# __str__ called.
# Python

# %%
str(p)
# Out:
# __str__ called.
# 'Python'

# %%
repr(p)
# Out:
# __repr__ called
# "Person(name='Python', age=30)"

# %%
class Person:
    pass

class Point:
    pass

# %%
person = Person()
point = Point()

# %%
repr(person), repr(point)
# Out:
# ('<__main__.Person object at 0x7fc9c6bf6de0>',
#  '<__main__.Point object at 0x7fc9c6bf7710>')

# %%
str(person), str(point)
# Out:
# ('<__main__.Person object at 0x7fc9c6bf6de0>',
#  '<__main__.Point object at 0x7fc9c6bf7710>')

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # def __repr__(self):
    #     print('__repr__ called')
    #     return f"Person(name='{self.name}', age={self.age})"

    def __str__(self):
        print('__str__ called')
        return self.name

# %%
p = Person('Python', 30)

# %%
p

# %%
print(p)
# Out:
# __str__ called
# Python

# %%
str(p)
# Out:
# __str__ called
# 'Python'

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        print('__repr__ called')
        return f"Person(name='{self.name}', age={self.age})"

    def __str__(self):
        print('__str__ called')
        return self.name

# %%
p = Person('Python', 30)

# %%
f'The person is {p}'
# Out:
# __str__ called
# 'The person is Python'

# %%
'The person is {}'.format(p)
# Out:
# __str__ called
# 'The person is Python'

# %%
'The person is %s' % p
# Out:
# __str__ called
# 'The person is Python'
