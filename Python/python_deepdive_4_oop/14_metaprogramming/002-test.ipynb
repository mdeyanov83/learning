# %% [markdown]
# ### Decorators and Descriptors - Review

# %%
from functools import wraps

# %%
def debugger(fn):
    @wraps(fn)
    def inner(*args, **kwargs):
        print(f'{fn.__qualname__}', args, kwargs)
        return fn(*args, **kwargs)
    return inner

# %%
@debugger
def func_1(*args, **kwargs):
    pass

@debugger
def func_2(*args, **kwargs):
    pass

# %%
func_1(1, 20, kw='a')
# Out:
# func_1 (1, 20) {'kw': 'a'}

# %%
func_2(10)
# Out:
# func_2 (10,) {}

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

# %%
p = Point(10, 20)

# %%
p.x, p.y
# Out:
# (10, 20)

# %%
p.__dict__
# Out:
# {'x': 10, 'y': 20}

# %%
class IntegerField:
    def __set_name__(self, onwer, name):
        self.name = name

    def __get__(self, instance, onwer):
        print('__get__ called...')
        return instance.__dict__.get(self.name, None)

    def __set__(self, instance, value):
        print('__set__ called ...')
        if not isinstance(value, int):
            raise TypeError('Must be an integer')
        instance.__dict__[self.name] = value

# %%
class Point:
    x = IntegerField()
    y = IntegerField()

    def __init__(self, x, y):
        self.x = x
        self.y = y

# %%
p = Point(10, 20)
# Out:
# __set__ called ...
# __set__ called ...

# %%
p.x, p.y
# Out:
# __get__ called...
# __get__ called...
# (10, 20)

# %%
p.x = 10.5
# Out:
# __set__ called ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 p.x = 10.5
#
# Cell In[14], line 12, in IntegerField.__set__(self, instance, value)
#      10 print('__set__ called ...')
#      11 if not isinstance(value, int):
# ---> 12     raise TypeError('Must be an integer')
#      13 instance.__dict__[self.name] = value
#
# TypeError: Must be an integer
