# %% [markdown]
# ### Creating Attributes at Run-Time

# %%
class Person:
    pass

# %%
p1 = Person()
p2 = Person()

p1.name = 'Alex'

# %%
p1.__dict__
# Out:
# {'name': 'Alex'}

# %%
p2.__dict__
# Out:
# {}

# %%
p1.say_hello = lambda: 'Hello!'

# %%
p1.say_hello
# Out:
# <function __main__.<lambda>()>

# %%
p1.__dict__
# Out:
# {'name': 'Alex', 'say_hello': <function __main__.<lambda>()>}

# %%
from types import MethodType

# %%
class Person:
    def __init__(self, name):
        self.name = name

# %%
p1 = Person('Eric')

# %%
p2 = Person('Alex')

# %%
p1.__dict__, p2.__dict__
# Out:
# ({'name': 'Eric'}, {'name': 'Alex'})

# %%
def say_hello(self):
    return f'{self.name} says hello!'

# %%
say_hello(p1)
# Out:
# 'Eric says hello!'

# %%
say_hello(p2)
# Out:
# 'Alex says hello!'

# %%
p1.say_hello = MethodType(say_hello, p1)

# %%
p1.say_hello()
# Out:
# 'Eric says hello!'

# %%
p1.__dict__
# Out:
# {'name': 'Eric',
#  'say_hello': <bound method say_hello of <__main__.Person object at 0x7fa6f8666d20>>}

# %%
hex(id(p1))
# Out:
# '0x7fa6f8666d20'

# %%
getattr(p1, 'say_hello')()
# Out:
# 'Eric says hello!'

# %%
p1 = Person('Alex')

# %%
p1.say_hello = MethodType(lambda self: f'{self.name} says hello', p1)

# %%
p1.say_hello()
# Out:
# 'Alex says hello'

# %%
p1 = Person('Alex')
p2 = Person('Eric')

# %%
p1.say_hello = MethodType(lambda self: f'{self.name} says hello', p2)

# %%
p1.say_hello()
# Out:
# 'Eric says hello'

# %%
p1.__dict__
# Out:
# {'name': 'Alex',
#  'say_hello': <bound method <lambda> of <__main__.Person object at 0x7fa6f869ecc0>>}

# %%
p2.__dict__
# Out:
# {'name': 'Eric'}

# %%
hex(id(p1)), hex(id(p2))
# Out:
# ('0x7fa6f869fd40', '0x7fa6f869ecc0')

# %%
from types import MethodType

class Person:
    def __init__(self, name):
        self.name = name

    def register_do_work(self, func):
        # setattr(self, '_do_work', MethodType(func, self))
        self._do_work = MethodType(func, self)

    def do_work(self):
        do_work_method = getattr(self, '_do_work', None)

        if do_work_method:
            return do_work_method()
        else:
            raise AttributeError('You must first register a do_work method.')

# %%
math_teacher = Person('Eric')
english_teacher = Person('John')

# %%
math_teacher.do_work()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 math_teacher.do_work()
#
# Cell In[34], line 17, in Person.do_work(self)
#      15     return do_work_method()
#      16 else:
# ---> 17     raise AttributeError('You must first register a do_work method.')
#
# AttributeError: You must first register a do_work method.

# %%
def work_math(self):
    return f'{self.name} will teach differentials today.'

# %%
math_teacher.register_do_work(work_math)

# %%
math_teacher.__dict__
# Out:
# {'name': 'Eric',
#  '_do_work': <bound method work_math of <__main__.Person object at 0x7fa6f86bf0e0>>}

# %%
math_teacher.do_work()
# Out:
# 'Eric will teach differentials today.'

# %%
def work_english(self):
    return f'{self.name} will analyze Hamlet today.'

# %%
english_teacher.register_do_work(work_english)

# %%
english_teacher.__dict__
# Out:
# {'name': 'John',
#  '_do_work': <bound method work_english of <__main__.Person object at 0x7fa6f86be4b0>>}

# %%
english_teacher.do_work()
# Out:
# 'John will analyze Hamlet today.'

# %%
persons = [math_teacher, english_teacher]

# %%
for p in persons:
    print(p.do_work())
# Out:
# Eric will teach differentials today.
# John will analyze Hamlet today.
