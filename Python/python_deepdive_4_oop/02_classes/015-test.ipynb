# %% [markdown]
# ### Initializing Class Instances

# %%
class Person:
    def __init__(self):
        print(f'Initializing a new Person object: {self}')

# %%
p = Person()
# Out:
# Initializing a new Person object: <__main__.Person object at 0x7f8644926630>

# %%
hex(id(p))
# Out:
# '0x7f8644926630'

# %%
class Person:
    def __init__(self, name):
        self.name = name

# %%
p = Person('Eric')

# %%
p

# %%
p.name
# Out:
# 'Eric'

# %%
p.__dict__
# Out:
# {'name': 'Eric'}

# %%
class Person:
    def init(self, name):
        self.name = name

# %%
p = Person()

# %%
p.__dict__
# Out:
# {}

# %%
p.init('Eric')

# %%
p.__dict__
# Out:
# {'name': 'Eric'}
