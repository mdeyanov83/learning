# %% [markdown]
# ### Hashing and Equality

# %%
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
class Person:
    pass

# %%
p1 = Person()
p2 = Person()

# %%
hash(p1), hash(p2)
# Out:
# (8772211236862, 8772211236529)

# %%
p1 == p2
# Out:
# False

# %%
p1 is p2
# Out:
# False
