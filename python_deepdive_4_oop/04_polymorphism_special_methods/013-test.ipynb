# %% [markdown]
# ### Making Objects Callable

# %%
class Person:
    def __call__(self):
        print('__call__ called...')

# %%
p = Person()

# %%
p()
# Out:
# __call__ called...

# %%
type(p)
# Out:
# __main__.Person

# %%
from functools import partial

# %%
type(partial)
# Out:
# type

# %%
type(Person)
# Out:
# type
