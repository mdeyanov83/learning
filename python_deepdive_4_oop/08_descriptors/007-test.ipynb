# %% [markdown]
# ### Using as Instance Properties

# %%
class IntegerValue:
    def __set__(self, instance, value):
        instance.stored_value = int(value)

    def __get__(self, instance, owner_class):
        if instance is None:
            return self
        return getattr(instance, 'stored_value', None)

# %%
class Point1D:
    x = IntegerValue()

# %%
p1, p2 = Point1D(), Point1D()

# %%
p1.x = 10.1
p2.x = 20.2

# %%
p1.x, p2.x
# Out:
# (10, 20)

# %%
class Point2D:
    x = IntegerValue()
    y = IntegerValue()

# %%
p = Point2D()

# %%
p.x = 10.1

# %%
p.x
# Out:
# 10

# %%
p.__dict__
# Out:
# {'stored_value': 10}

# %%
p.y = 20.2

# %%
p.y
# Out:
# 20

# %%
p.__dict__
# Out:
# {'stored_value': 20}

# %%
p.x
# Out:
# 20

# %%
class IntegerValue:
    def __init__(self, name):
        self.storage_name = '_' + name

    def __set__(self, instance, value):
        setattr(instance, self.storage_name, value)


    def __get__(self, instance, owner_class):
        if instance is None:
            return self
        return getattr(instance, self.storage_name, None)

# %%
class Point2D:
    x = IntegerValue('x')
    y = IntegerValue('y')

# %%
p1, p2 = Point2D(), Point2D()

# %%
p1.x = 10.1
p1.y = 20.2

# %%
p1.__dict__
# Out:
# {'_x': 10.1, '_y': 20.2}

# %%
p2.__dict__
# Out:
# {}

# %%
p2.x = 100.1
p2.y = 200.2

# %%
p2.__dict__
# Out:
# {'_x': 100.1, '_y': 200.2}

# %%
p1 = Point2D()

# %%
p1._x = 100

# %%
p1.__dict__
# Out:
# {'_x': 100}

# %%
p1.x = 200

# %%
p1.__dict__
# Out:
# {'_x': 200}

# %%
class IntegerValue:
    def __init__(self):
        self.values = {}

    def __set__(self, instance, value):
        self.values[instance] = int(value)

    def __get__(self, instance, owner_class):
        if instance is None:
            return self
        return self.values.get(instance)

# %%
class Point2D:
    x = IntegerValue()
    y = IntegerValue()

# %%
p1 = Point2D()
p2 = Point2D()

# %%
p1.x = 10.1
p1.y = 20.2

# %%
p1.x, p1.y
# Out:
# (10, 20)

# %%
Point2D.x.values
# Out:
# {<__main__.Point2D at 0x7fbc70309e80>: 10}

# %%
hex(id(p1))
# Out:
# '0x7fbc70309e80'

# %%
p2.x = 100.1

# %%
Point2D.x.values
# Out:
# {<__main__.Point2D at 0x7fbc70309e80>: 10,
#  <__main__.Point2D at 0x7fbc70309dc0>: 100}

# %%
Point2D.y.values
# Out:
# {<__main__.Point2D at 0x7fbc70309e80>: 20}

# %%
p2.y = 200

# %%
Point2D.y.values
# Out:
# {<__main__.Point2D at 0x7fbc70309e80>: 20,
#  <__main__.Point2D at 0x7fbc70309dc0>: 200}

# %%
hex(id(p1))
# Out:
# '0x7fbc70309e80'

# %%
del p1

# %%
Point2D.x.values
# Out:
# {<__main__.Point2D at 0x7fbc70309e80>: 10,
#  <__main__.Point2D at 0x7fbc70309dc0>: 100}

# %%
p1 = list(Point2D.x.values.keys())[0]

# %%
p1

# %%
p1.x, p1.y
# Out:
# (10, 20)

# %%
import ctypes

# %%
def ref_count(address):
    return ctypes.c_long.from_address(address).value

# %%
p1 = Point2D()
id_p1 = id(p1)

# %%
ref_count(id_p1)
# Out:
# 1

# %%
p1.x = 100.1

# %%
ref_count(id_p1)
# Out:
# 2

# %%
'p1' in globals()
# Out:
# True

# %%
del p1

# %%
'p1' in globals()
# Out:
# False

# %%
ref_count(id_p1)
# Out:
# 1
