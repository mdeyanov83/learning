# %% [markdown]
# ### Strong and Weak References

# %%
import ctypes

def ref_count(address):
    return ctypes.c_long.from_address(address).value

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f'Person(name={self.name})'

# %%
p1 = Person('Guido')
p2 = p1

# %%
p1 is p2, id(p1), id(p2)
# Out:
# (True, 140368873089664, 140368873089664)

# %%
ref_count(id(p1))
# Out:
# 2

# %%
del p2

# %%
ref_count(id(p1))
# Out:
# 1

# %%
p1_id = id(p1)

# %%
ref_count(p1_id)
# Out:
# 1

# %%
del p1

# %%
ref_count(p1_id)
# Out:
# 11756008

# %%
import weakref

# %%
p1 = Person('Guido')
p1_id = id(p1)

# %%
ref_count(p1_id)
# Out:
# 1

# %%
p2 = p1
ref_count(p1_id)
# Out:
# 2

# %%
weak1 = weakref.ref(p1)

# %%
ref_count(p1_id)
# Out:
# 2

# %%
weak1
# Out:
# <weakref at 0x7faa2cd44bd0; to 'Person' at 0x7faa2cd482c0>

# %%
weak1 is p1
# Out:
# False

# %%
weak1() is p1
# Out:
# True

# %%
print(p1)
# Out:
# Person(name=Guido)

# %%
ref_count(p1_id)
# Out:
# 2

# %%
print(weak1)
print(weak1())
# Out:
# <weakref at 0x7faa2cd44bd0; to 'Person' at 0x7faa2cd482c0>
# Person(name=Guido)

# %%
ref_count(p1_id)
# Out:
# 2

# %%
p3 = weak1()

# %%
ref_count(p1_id)
# Out:
# 3

# %%
del p3

# %%
ref_count(p1_id)
# Out:
# 2

# %%
del p2
ref_count(p1_id)
# Out:
# 1

# %%
print(weak1())
# Out:
# Person(name=Guido)

# %%
weak1
# Out:
# <weakref at 0x7faa2cd44bd0; to 'Person' at 0x7faa2cd482c0>

# %%
del p1

# %%
ref_count(p1_id)
# Out:
# 0

# %%
weak1
# Out:
# <weakref at 0x7faa2cd44bd0; dead>

# %%
result = weak1()

# %%
print(result)
# Out:
# None

# %%
l = 'python'
try:
    weakref.ref(l)
except TypeError as ex:
    print(ex)
# Out:
# cannot create weak reference to 'str' object

# %%
p1 = Person('Guido')

# %%
d = weakref.WeakKeyDictionary()

# %%
ref_count(id(p1))
# Out:
# 1

# %%
n = {p1: 'Guido'}

# %%
ref_count(id(p1))
# Out:
# 2

# %%
del n

# %%
ref_count(id(p1))
# Out:
# 1

# %%
d[p1] = 'Guido'

# %%
ref_count(id(p1))
# Out:
# 1

# %%
weakref.getweakrefcount(p1)
# Out:
# 1

# %%
d2 = weakref.WeakKeyDictionary()
d2[p1] = 'Guido'

# %%
ref_count(id(p1)), weakref.getweakrefcount(p1)
# Out:
# (1, 2)

# %%
p1.__weakref__
# Out:
# <weakref at 0x7faa2cde2a20; to 'Person' at 0x7faa2cdb7fe0>

# %%
hex(id(p1))
# Out:
# '0x7faa2cdb7fe0'

# %%
list(d.keyrefs())
# Out:
# [<weakref at 0x7faa2cd61a80; to 'Person' at 0x7faa2cdb7fe0>]

# %%
del p1

# %%
list(d.keyrefs())
# Out:
# []

# %%
d['python'] = 'test'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 d['python'] = 'test'
#
# File /usr/lib/python3.12/weakref.py:428, in WeakKeyDictionary.__setitem__(self, key, value)
#     427 def __setitem__(self, key, value):
# --> 428     self.data[ref(key, self._remove)] = value
#
# TypeError: cannot create weak reference to 'str' object

# %%
class Person():
    def __init__(self, name):
        self.name = name

# %%
p = Person('Alex')

# %%
hash(p)
# Out:
# 8773054609046

# %%
d[p] = 'Alex'

# %%
list(d.keyrefs())
# Out:
# [<weakref at 0x7faa2c410f40; to 'Person' at 0x7faa2cdb6960>]

# %%
class Person():
    def __init__(self, name):
        self.name = name

    def __eq__(self, other):
        return isinstance(other, Person) and self.name == other.name

# %%
p1 = Person('Guido')
p2 = Person('Guido')

# %%
p1 == p2
# Out:
# True

# %%
hash(p1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 hash(p1)
#
# TypeError: unhashable type: 'Person'

# %%
d[p1] = 'test'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 d[p1] = 'test'
#
# File /usr/lib/python3.12/weakref.py:428, in WeakKeyDictionary.__setitem__(self, key, value)
#     427 def __setitem__(self, key, value):
# --> 428     self.data[ref(key, self._remove)] = value
#
# TypeError: unhashable type: 'Person'

# %%
class Person():
    def __init__(self, name):
        self.name = name

    def __eq__(self, other):
        return isinstance(other, Person) and self.name == other.name

    def __hash__(self):
        return hash(self.name)

# %%
p1 = Person('Guido')
p2 = Person('Guido')

# %%
p1 == p2
# Out:
# True

# %%
hash(p1)
# Out:
# 993875799131414753

# %%
d[p1] = 'test'

# %%
list(d.keyrefs())
# Out:
# [<weakref at 0x7faa2c410f40; to 'Person' at 0x7faa2cdb6960>,
#  <weakref at 0x7faa0fc484f0; to 'Person' at 0x7faa2c30c5c0>]

# %%
del p1

# %%
list(d.keyrefs())
# Out:
# [<weakref at 0x7faa2c410f40; to 'Person' at 0x7faa2cdb6960>]
