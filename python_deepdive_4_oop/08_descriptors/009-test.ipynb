# %% [markdown]
# ### Strong and Weak References

# %%
import ctypes

def ref_count(address):
    return ctypes.c_long.from_address(address).value

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return f'Person(name={self.name})'

# %%
p1 = Person('Guido')
p2 = p1

# %%
p1 is p2, id(p1), id(p2)
# Out:
# (True, 140227668265200, 140227668265200)

# %%
ref_count(id(p1))
# Out:
# 2

# %%
del p2

# %%
ref_count(id(p1))
# Out:
# 1

# %%
p1_id = id(p1)

# %%
ref_count(p1_id)
# Out:
# 1

# %%
del p1

# %%
ref_count(p1_id)
# Out:
# 140227666523136

# %%
import weakref

# %%
p1 = Person('Guido')
p1_id = id(p1)

# %%
ref_count(p1_id)
# Out:
# 1

# %%
p2 = p1
ref_count(p1_id)
# Out:
# 2

# %%
weak1 = weakref.ref(p1)

# %%
ref_count(p1_id)
# Out:
# 2

# %%
weak1
# Out:
# <weakref at 0x7f8954439440; to 'Person' at 0x7f894c5830b0>

# %%
weak1 is p1
# Out:
# False

# %%
weak1() is p1
# Out:
# True

# %%
print(p1)
# Out:
# Person(name=Guido)

# %%
ref_count(p1_id)
# Out:
# 5

# %%
print(weak1)
print(weak1())
# Out:
# <weakref at 0x7f8954439440; to 'Person' at 0x7f894c5830b0>
# Person(name=Guido)

# %%
ref_count(p1_id)
# Out:
# 5
