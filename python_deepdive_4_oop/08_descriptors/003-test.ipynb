# %% [markdown]
# ### Descriptors

# %%
from datetime import datetime

# %%
class TimeUTC:
    def __get__(self, instance, owner_class):
        return datetime.now().isoformat()

# %%
class Logger:
    current_time = TimeUTC()

# %%
Logger.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'current_time': <__main__.TimeUTC at 0x7fcec5371af0>,
#               '__dict__': <attribute '__dict__' of 'Logger' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Logger' objects>,
#               '__doc__': None})

# %%
Logger.current_time
# Out:
# '2026-01-27T12:18:32.827688'

# %%
l = Logger()

# %%
l.current_time
# Out:
# '2026-01-27T12:18:45.051402'

# %%
from random import choice, seed

class Deck:
    @property
    def suit(self):
        return choice(('Spade', 'Heart', 'Diamond', 'Club'))

    @property
    def card(self):
        return choice(tuple('23456789JQKA') + ('10', ))

# %%
d = Deck()

# %%
seed(0)

for _ in range(10):
    print(d.card, d.suit)
# Out:
# 8 Club
# 2 Diamond
# J Club
# 8 Diamond
# 9 Diamond
# Q Heart
# J Heart
# 6 Heart
# 10 Spade
# Q Diamond

# %%
class Choice:
    def __init__(self, *choices):
        self.choices = choices

    def __get__(self, instance, owner_class):
        return choice(self.choices)

# %%
class Deck:
    suit = Choice('Spade', 'Heart', 'Diamond', 'Club')
    card = Choice(*'234567899JQKA', '10')

# %%
seed(0)
d = Deck()
for _ in range(10):
    print(d.card, d.suit)
# Out:
# 10 Club
# A Club
# 2 Diamond
# 9 Club
# 8 Diamond
# 9 Diamond
# J Heart
# 9 Heart
# 6 Heart
# A Spade

# %%
class Dice:
    die_1 = Choice(1, 2, 3, 4, 5, 6)
    die_2 = Choice(1, 2, 3, 4, 5, 6)
    die_3 = Choice(1, 2, 3, 4, 5, 6)

# %%
seed(0)
dice = Dice()

# %%
for _ in range(10):
    print(dice.die_1, dice.die_2, dice.die_3)
# Out:
# 4 4 1
# 3 5 4
# 4 3 4
# 3 5 2
# 5 2 3
# 2 1 5
# 3 5 6
# 5 2 3
# 1 6 1
# 6 3 4
