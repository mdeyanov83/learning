# %% [markdown]
# ### Raising Exceptions

# %%
class Person:
    pass

# %%
raise Person()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raise Person()
#
# TypeError: exceptions must derive from BaseException

# %%
ex = BaseException('a', 'b', 'c')

# %%
ex.args
# Out:
# ('a', 'b', 'c')

# %%
str(ex)
# Out:
# "('a', 'b', 'c')"

# %%
repr(ex)
# Out:
# "BaseException('a', 'b', 'c')"

# %%
ex = ValueError('a', 'b', 'c')

# %%
ex.args
# Out:
# ('a', 'b', 'c')

# %%
str(ex)
# Out:
# "('a', 'b', 'c')"

# %%
repr(ex)
# Out:
# "ValueError('a', 'b', 'c')"

# %%
try:
    raise ValueError
except ValueError as ex:
    print(ex.args)
# Out:
# ()

# %%
try:
    raise ValueError('some message', 100, 200)
except ValueError as ex:
    print(ex.args)
# Out:
# ('some message', 100, 200)

# %%
def div(a, b):
    try:
        return a//b
    except ZeroDivisionError as ex:
        print('logging exception...', repr(ex))
        raise

# %%
div(1, 0)
# Out:
# logging exception... ZeroDivisionError('integer division or modulo by zero')
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 div(1, 0)
#
# Cell In[14], line 3, in div(a, b)
#       1 def div(a, b):
#       2     try:
# ----> 3         return a//b
#       4     except ZeroDivisionError as ex:
#       5         print('logging exception...', repr(ex))
#
# ZeroDivisionError: integer division or modulo by zero

# %%
class CustomError(Exception):
    """a custom exception"""

# %%
def my_func(a, b):
    try:
        return a//b
    except ZeroDivisionError as ex:
        print('logging exception...', repr(ex))
        raise CustomError(*ex.args)

# %%
my_func(1, 0)
# Out:
# logging exception... ZeroDivisionError('integer division or modulo by zero')
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[26], line 3, in my_func(a, b)
#       2 try:
# ----> 3     return a//b
#       4 except ZeroDivisionError as ex:
#
# ZeroDivisionError: integer division or modulo by zero
#
# During handling of the above exception, another exception occurred:
#
# CustomError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 my_func(1, 0)
#
# Cell In[26], line 6, in my_func(a, b)
#       4 except ZeroDivisionError as ex:
#       5     print('logging exception...', repr(ex))
# ----> 6     raise CustomError(*ex.args)
#
# CustomError: integer division or modulo by zero

# %%
try:
    raise ValueError('level 1')
except ValueError:
    try:
        raise TypeError('level 2')
    except TypeError:
        raise KeyError('level 3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 try:
# ----> 2     raise ValueError('level 1')
#       3 except ValueError:
#
# ValueError: level 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 5
#       4 try:
# ----> 5     raise TypeError('level 2')
#       6 except TypeError:
#
# TypeError: level 2
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 7
#       5     raise TypeError('level 2')
#       6 except TypeError:
# ----> 7     raise KeyError('level 3')
#
# KeyError: 'level 3'

# %%
class ConversionError(Exception):
    pass

def convert_int(val):
    if not isinstance(val, int):  # remember this will work for booleans too!
        raise TypeError()
    if val not in {0, 1}:
        raise ValueError("Integer values 0 or 1 only")
    return bool(val)

def convert_str(val):
    if not isinstance(val, str):
        raise TypeError()

    val = val.casefold()  # for case-insensitive comparisons
    if val in {'0', 'f', 'false'}:
        return False
    elif val in {'1', 't', 'true'}:
        return True
    else:
        raise ValueError('Admissible string values are: T, F, True, False (case insensitive)')

def make_bool(val):
    try:
        try:
            b = convert_int(val)
        except TypeError:
            # it wasn't an int/bool, so let's try it as a string
            try:
                b = convert_str(val)
            except TypeError:
                raise ConversionError(f'The type {type(val).__name__} cannot be converted to a bool')
    except ValueError as ex:
        # this will catch ValueError exceptions from either convert_int or convert_str
        raise ConversionError(f'The value {val} cannot be converted to a bool: {ex}')
    else:
        return b

# %%
make_bool('ABC')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 26, in make_bool(val)
#      25 try:
# ---> 26     b = convert_int(val)
#      27 except TypeError:
#      28     # it wasn't an int/bool, so let's try it as a string
#
# Cell In[29], line 6, in convert_int(val)
#       5 if not isinstance(val, int):  # remember this will work for booleans too!
# ----> 6     raise TypeError()
#       7 if val not in {0, 1}:
#
# TypeError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 30, in make_bool(val)
#      29 try:
# ---> 30     b = convert_str(val)
#      31 except TypeError:
#
# Cell In[29], line 21, in convert_str(val)
#      20 else:
# ---> 21     raise ValueError('Admissible string values are: T, F, True, False (case insensitive)')
#
# ValueError: Admissible string values are: T, F, True, False (case insensitive)
#
# During handling of the above exception, another exception occurred:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 make_bool('ABC')
#
# Cell In[29], line 35, in make_bool(val)
#      32             raise ConversionError(f'The type {type(val).__name__} cannot be converted to a bool')
#      33 except ValueError as ex:
#      34     # this will catch ValueError exceptions from either convert_int or convert_str
# ---> 35     raise ConversionError(f'The value {val} cannot be converted to a bool: {ex}')
#      36 else:
#      37     return b
#
# ConversionError: The value ABC cannot be converted to a bool: Admissible string values are: T, F, True, False (case insensitive)

# %%
class ConversionError(Exception):
    pass

def convert_int(val):
    if not isinstance(val, int):  # remember this will work for booleans too!
        raise TypeError()
    if val not in {0, 1}:
        raise ValueError("Integer values 0 or 1 only")
    return bool(val)

def convert_str(val):
    if not isinstance(val, str):
        raise TypeError()

    val = val.casefold()  # for case-insensitive comparisons
    if val in {'0', 'f', 'false'}:
        return False
    elif val in {'1', 't', 'true'}:
        return True
    else:
        raise ValueError('Admissible string values are: T, F, True, False (case insensitive)')

def make_bool(val):
    try:
        try:
            b = convert_int(val)
        except TypeError:
            # it wasn't an int/bool, so let's try it as a string
            try:
                b = convert_str(val)
            except TypeError:
                raise ConversionError(f'The type {type(val).__name__} cannot be converted to a bool') from None
    except ValueError as ex:
        # this will catch ValueError exceptions from either convert_int or convert_str
        raise ConversionError(f'The value {val} cannot be converted to a bool: {ex}') from None
    else:
        return b

# %%
make_bool('ABC')
# Out:
# ---------------------------------------------------------------------------
# ConversionError                           Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 make_bool('ABC')
#
# Cell In[32], line 35, in make_bool(val)
#      32             raise ConversionError(f'The type {type(val).__name__} cannot be converted to a bool') from None
#      33 except ValueError as ex:
#      34     # this will catch ValueError exceptions from either convert_int or convert_str
# ---> 35     raise ConversionError(f'The value {val} cannot be converted to a bool: {ex}') from None
#      36 else:
#      37     return b
#
# ConversionError: The value ABC cannot be converted to a bool: Admissible string values are: T, F, True, False (case insensitive)

# %%
try:
    raise ValueError('level 1')
except ValueError as ex_1:
    try:
        raise ValueError('level 2')
    except ValueError as ex_2:
        try:
            raise ValueError('level 3')
        except ValueError as ex_3:
            raise ValueError('Value Error occurred')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 try:
# ----> 2     raise ValueError('level 1')
#       3 except ValueError as ex_1:
#
# ValueError: level 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 5
#       4 try:
# ----> 5     raise ValueError('level 2')
#       6 except ValueError as ex_2:
#
# ValueError: level 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 8
#       7 try:
# ----> 8     raise ValueError('level 3')
#       9 except ValueError as ex_3:
#
# ValueError: level 3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 10
#       8     raise ValueError('level 3')
#       9 except ValueError as ex_3:
# ---> 10     raise ValueError('Value Error occurred')
#
# ValueError: Value Error occurred

# %%
try:
    raise ValueError('level 1')
except ValueError as ex_1:
    try:
        raise ValueError('level 2')
    except ValueError as ex_2:
        try:
            raise ValueError('level 3')
        except ValueError as ex_3:
            raise ValueError('Value Error occurred') from None
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 10
#       8     raise ValueError('level 3')
#       9 except ValueError as ex_3:
# ---> 10     raise ValueError('Value Error occurred') from None
#
# ValueError: Value Error occurred

# %%
try:
    raise ValueError('level 1')
except ValueError as ex_1:
    try:
        raise ValueError('level 2')
    except ValueError as ex_2:
        try:
            raise ValueError('level 3')
        except ValueError as ex_3:
            raise ex_1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 5
#       4 try:
# ----> 5     raise ValueError('level 2')
#       6 except ValueError as ex_2:
#
# ValueError: level 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 8
#       7 try:
# ----> 8     raise ValueError('level 3')
#       9 except ValueError as ex_3:
#
# ValueError: level 3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 10
#       8     raise ValueError('level 3')
#       9 except ValueError as ex_3:
# ---> 10     raise ex_1
#
# Cell In[36], line 2
#       1 try:
# ----> 2     raise ValueError('level 1')
#       3 except ValueError as ex_1:
#       4     try:
#
# ValueError: level 1

# %%
try:
    raise ValueError('level 1')
except ValueError as ex_1:
    try:
        raise ValueError('level 2')
    except ValueError as ex_2:
        try:
            raise ValueError('level 3')
        except ValueError as ex_3:
            raise ValueError('cannot recover') from ex_1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 try:
# ----> 2     raise ValueError('level 1')
#       3 except ValueError as ex_1:
#
# ValueError: level 1
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 10
#       8     raise ValueError('level 3')
#       9 except ValueError as ex_3:
# ---> 10     raise ValueError('cannot recover') from ex_1
#
# ValueError: cannot recover
