# %% [markdown]
# ### Handling Exceptions

# %%
raise ValueError('custom exception')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 raise ValueError('custom exception')
#
# ValueError: custom exception

# %%
try:
    raise ValueError('custom message', 'secondary message')
except ValueError as ex:
    print(ex)
    print(repr(ex))
# Out:
# ('custom message', 'secondary message')
# ValueError('custom message', 'secondary message')

# %%
def func_1():
    # raise ValueError('bad value')
    # raise IndexError('bad index')
    raise TypeError('bad type')

# %%
try:
    func_1()
except ValueError as ex:
    print('handling a value error', repr(ex))
except IndexError as ex:
    print('handling an index error', repr(ex))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 try:
# ----> 2     func_1()
#       3 except ValueError as ex:
#       4     print('handling a value error', repr(ex))
#
# Cell In[9], line 4, in func_1()
#       1 def func_1():
#       2     # raise ValueError('bad value')
#       3     # raise IndexError('bad index')
# ----> 4     raise TypeError('bad type')
#
# TypeError: bad type

# %%
try:
    raise ValueError('error')
except ValueError as ex:
    print('handling value exception', repr(ex))
except Exception as ex:
    print('handling exception', repr(ex))
# Out:
# handling value exception ValueError('error')
