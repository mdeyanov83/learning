# %% [markdown]
# ### Metaprogramming - Application 2

# %%
NoneType = type(None)

# %%
n1 = NoneType
n2 = NoneType

# %%
n1, n2
# Out:
# (NoneType, NoneType)

# %%
id(n1), id(n2)
# Out:
# (10746048, 10746048)
