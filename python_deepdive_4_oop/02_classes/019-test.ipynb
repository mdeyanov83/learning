# %% [markdown]
# ### Properties

# %%
class Person:
    def __init__(self, name):
        self.name = name

# %%
p = Person('Alex')

# %%
p.__dict__
# Out:
# {'name': 'Alex'}

# %%
p.name = 100

# %%
p.name = ''

# %%
class Person
