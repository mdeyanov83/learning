# %% [markdown]
# ### Properties

# %%
class Person:
    def __init__(self, name):
        self.name = name

# %%
p = Person('Alex')

# %%
p.__dict__
# Out:
# {'name': 'Alex'}

# %%
p.name = 100

# %%
p.name = ''

# %%
class Person:
    def __init__(self, name):
        self.set_name(name)

    def get_name(self):
        return self._name

    def set_name(self, value):
        if isinstance(value, str) and len(value.strip()) > 0:
            self._name = value.strip()
        else:
            raise ValueError('Name must be a non-empty string')

# %%
p = Person('Alex')

# %%
try:
    p.set_name(300)
except ValueError as ex:
    print(ex)
# Out:
# Name must be a non-empty string

# %%
p.__dict__
# Out:
# {'_name': 'Alex'}

# %%
type(property())
# Out:
# property

# %%
a = property()

# %%
class Person:
    def __init__(self, name):
        self._name = name

    def get_name(self):
        print('getter called...')
        return self._name

    def set_name(self, value):
        print('setter called...')
        if isinstance(value, str) and len(value.strip()) > 0:
            self._name = value.strip()
        else:
            raise ValueError('Name must be a non-empty string')

    name = property(fget=get_name, fset=set_name)

# %%
p = Person('Alex')

# %%
p.__dict__
# Out:
# {'_name': 'Alex'}

# %%
p.name
# Out:
# getter called...
# 'Alex'

# %%
p.name = ''
# Out:
# setter called...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 p.name = ''
#
# Cell In[29], line 14, in Person.set_name(self, value)
#      12     self._name = value.strip()
#      13 else:
# ---> 14     raise ValueError('Name must be a non-empty string')
#
# ValueError: Name must be a non-empty string

# %%
p.name = 'Eric'
# Out:
# setter called...

# %%
p.__dict__
# Out:
# {'_name': 'Eric'}

# %%
getattr(p, 'name')
# Out:
# getter called...
# 'Eric'

# %%
setattr(p, 'name', 'John')
# Out:
# setter called...

# %%
p.__dict__
# Out:
# {'_name': 'John'}

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__init__': <function __main__.Person.__init__(self, name)>,
#               'get_name': <function __main__.Person.get_name(self)>,
#               'set_name': <function __main__.Person.set_name(self, value)>,
#               'name': <property at 0x7f290094fce0>,
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>,
#               '__doc__': None})

# %%
p = Person('Alex')

# %%
p.name
# Out:
# getter called...
# 'Alex'

# %%
p.__dict__
# Out:
# {'_name': 'Alex'}

# %%
p.__dict__['_name']
# Out:
# 'Alex'

# %%
p._name
# Out:
# 'Alex'

# %%
p.name = 'Raymond'
# Out:
# setter called...

# %%
p.__dict__
# Out:
# {'_name': 'Raymond'}

# %%
p.__dict__['name'] = 'John'

# %%
p.__dict__
# Out:
# {'_name': 'Raymond', 'name': 'John'}

# %%
p.name
# Out:
# getter called...
# 'Raymond'

# %%
getattr(p, 'name')
# Out:
# getter called...
# 'Raymond'

# %%
class Person:
    def __init__(self, name):
        self._name = name

    def get_name(self):
        print('getter called...')
        return self._name

    def set_name(self, value):
        print('setter called...')
        if isinstance(value, str) and len(value.strip()) > 0:
            self._name = value.strip()
        else:
            raise ValueError('Name must be a non-empty string')

    def del_name(self):
        print('deleted called...')
        del self._name

    name = property(fget=get_name, fset=set_name, fdel=del_name)

# %%
p = Person('Aelx')

# %%
p.__dict__
# Out:
# {'_name': 'Aelx'}

# %%
p.name
# Out:
# getter called...
# 'Aelx'

# %%
p.name = 'Eric'
# Out:
# setter called...

# %%
p.name
# Out:
# getter called...
# 'Eric'

# %%
del p.name
# Out:
# deleted called...

# %%
p.__dict__
# Out:
# {}

# %%
Person.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__doc__': 'This is a Person object',
#               '__init__': <function __main__.Person.__init__(self, name)>,
#               'get_name': <function __main__.Person.get_name(self)>,
#               'set_name': <function __main__.Person.set_name(self, value)>,
#               'del_name': <function __main__.Person.del_name(self)>,
#               'name': <property at 0x7f2901886cf0>,
#               '__dict__': <attribute '__dict__' of 'Person' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Person' objects>})

# %%
p.name
# Out:
# getter called...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 p.name
#
# Cell In[72], line 9, in Person.get_name(self)
#       7 def get_name(self):
#       8     print('getter called...')
# ----> 9     return self._name
#
# AttributeError: 'Person' object has no attribute '_name'

# %%
p.name = 'Alex'
# Out:
# setter called...

# %%
p.__dict__
# Out:
# {'_name': 'Alex'}

# %%
p.name
# Out:
# getter called...
# 'Alex'

# %%
class Person:
    """This is a Person object"""

    def __init__(self, name):
        self._name = name

    def get_name(self):
        print('getter called...')
        return self._name

    def set_name(self, value):
        print('setter called...')
        if isinstance(value, str) and len(value.strip()) > 0:
            self._name = value.strip()
        else:
            raise ValueError('Name must be a non-empty string')

    def del_name(self):
        print('deleted called...')
        del self._name

    name = property(fget=get_name, fset=set_name, fdel=del_name, doc="The person's name")

# %%
help(Person)
# Out:
# Help on class Person in module __main__:
#
# class Person(builtins.object)
#  |  Person(name)
#  |
#  |  This is a Person object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  del_name(self)
#  |
#  |  get_name(self)
#  |
#  |  set_name(self, value)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  name
#  |      The person's name

# %%
help(Person.name)
# Out:
# Help on property:
#
#     The person's name

# %%
help(p)
# Out:
# Help on Person in module __main__ object:
#
# class Person(builtins.object)
#  |  Person(name)
#  |
#  |  This is a Person object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name)
#  |
#  |  del_name(self)
#  |
#  |  get_name(self)
#  |
#  |  set_name(self, value)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  name
#  |      The person's name
