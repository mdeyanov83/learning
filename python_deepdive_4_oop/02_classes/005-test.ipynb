# %% [markdown]
# ### Class Attributes

# %%
class Person:
    pass

# %%
Person.__name__
# Out:
# 'Person'

# %%
class Program:
    language = 'Python'
    version = '3.6'

# %%
type(Program)
# Out:
# type

# %%
Program.language
# Out:
# 'Python'

# %%
Program.version
# Out:
# '3.6'

# %%
Program.version = '3.7'

# %%
Program.version
# Out:
# '3.7'

# %%
getattr(Program, 'version')
# Out:
# '3.7'
