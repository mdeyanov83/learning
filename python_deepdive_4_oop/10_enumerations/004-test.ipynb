# %% [markdown]
# ### Enumerations

# %%
import enum

# %%
class Color(enum.Enum):
    red = 1
    green = 2
    blue = 3

# %%
class Status(enum.Enum):
    PENDING = 'pending'
    RUNNING = 'running'
    COMPLETED = 'completed'

# %%
class UnitVector(enum.Enum):
    V1D = (1, )
    V2D = (1, 1)
    V3D = (1, 1, 1)

# %%
Status.PENDING
# Out:
# <Status.PENDING: 'pending'>

# %%
type(Status.PENDING)
# Out:
# <enum 'Status'>

# %%
isinstance(Status.PENDING, Status)
# Out:
# True

# %%
Status.PENDING.name, Status.PENDING.value
# Out:
# ('PENDING', 'pending')

# %%
UnitVector.V3D
# Out:
# <UnitVector.V3D: (1, 1, 1)>

# %%
UnitVector.V3D.value
# Out:
# (1, 1, 1)

# %%
a = Status.PENDING

# %%
a is Status.PENDING
# Out:
# True

# %%
class Constants(enum.Enum):
    ONE = 1
    TWO = 2
    THREE = 3

# %%
Constants.ONE < Constants.TWO
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 Constants.ONE < Constants.TWO
#
# TypeError: '<' not supported between instances of 'Constants' and 'Constants'

# %%
Status.PENDING in Status
# Out:
# True

# %%
Status.PENDING.name, Status.PENDING.value
# Out:
# ('PENDING', 'pending')

# %%
'PENDING' in Status, 'pending' in Status
# Out:
# (False, True)

# %%
Status('pending'), UnitVector((1,1))
# Out:
# (<Status.PENDING: 'pending'>, <UnitVector.V2D: (1, 1)>)

# %%
Status('invalid')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 Status('invalid')
#
# File /usr/lib/python3.12/enum.py:757, in EnumType.__call__(cls, value, names, module, qualname, type, start, boundary, *values)
#     755     if names is not _not_given:
#     756         value = (value, names) + values
# --> 757     return cls.__new__(cls, value)
#     758 # otherwise, functional API: we're creating a new Enum type
#     759 if names is _not_given and type is None:
#     760     # no body? no data-type? possibly wrong usage
#
# File /usr/lib/python3.12/enum.py:1171, in Enum.__new__(cls, value)
#    1169 ve_exc = ValueError("%r is not a valid %s" % (value, cls.__qualname__))
#    1170 if result is None and exc is None:
# -> 1171     raise ve_exc
#    1172 elif exc is None:
#    1173     exc = TypeError(
#    1174             'error in %s._missing_: returned %r instead of None or a valid member'
#    1175             % (cls.__name__, result)
#    1176             )
#
# ValueError: 'invalid' is not a valid Status

# %%
class Person:
    def __getitem__(self, val):
        return f'__getitem__({val}) called...'

# %%
p = Person()

# %%
p['some value']
# Out:
# '__getitem__(some value) called...'

# %%
hasattr(Status, '__getitem__')
# Out:
# True

# %%
Status['PENDING']
# Out:
# <Status.PENDING: 'pending'>

# %%
getattr(Status, 'PENDING')
# Out:
# <Status.PENDING: 'pending'>

# %%
getattr(Status, 'INVALID', Status.PENDING)
# Out:
# <Status.PENDING: 'pending'>

# %%
class Person:
    __hash__ = None

# %%
p = Person()

# %%
hash(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 hash(p)
#
# TypeError: unhashable type: 'Person'

# %%
class Family(enum.Enum):
    person_1 = Person()
    person_2 = Person()

# %%
Family.person_1
# Out:
# <Family.person_1: <__main__.Person object at 0x7f5b88b784a0>>

# %%
{
    Family.person_1: 'person 1',
    Family.person_2: 'person 2'
}
# Out:
# {<Family.person_1: <__main__.Person object at 0x7f5b88b784a0>>: 'person 1',
#  <Family.person_2: <__main__.Person object at 0x7f5b88b02ff0>>: 'person 2'}

# %%
hasattr(Status, '__iter__')
# Out:
# True

# %%
for member in Status:
    print(repr(member))
# Out:
# <Status.PENDING: 'pending'>
# <Status.RUNNING: 'running'>
# <Status.COMPLETED: 'completed'>

# %%
list(Status)
# Out:
# [<Status.PENDING: 'pending'>,
#  <Status.RUNNING: 'running'>,
#  <Status.COMPLETED: 'completed'>]

# %%
list(Status)[0] is Status.PENDING
# Out:
# True

# %%
class Numbers1(enum.Enum):
    ONE = 1
    TWO = 2
    THREE = 3

class Numbers2(enum.Enum):
    THREE = 3
    TWO = 2
    ONE = 1

# %%
list(Numbers1)
# Out:
# [<Numbers1.ONE: 1>, <Numbers1.TWO: 2>, <Numbers1.THREE: 3>]

# %%
list(Numbers2)
# Out:
# [<Numbers2.THREE: 3>, <Numbers2.TWO: 2>, <Numbers2.ONE: 1>]

# %%
Status.PENDING.value = 10
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 Status.PENDING.value = 10
#
# File /usr/lib/python3.12/enum.py:230, in property.__set__(self, instance, value)
#     228 if self.fset is not None:
#     229     return self.fset(instance, value)
# --> 230 raise AttributeError(
#     231         "<enum %r> cannot set attribute %r" % (self.clsname, self.name)
#     232         )
#
# AttributeError: <enum 'Enum'> cannot set attribute 'value'

# %%
Status['NEW'] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 Status['NEW'] = 100
#
# TypeError: 'EnumType' object does not support item assignment

# %%
class EnumBase(enum.Enum):
    pass

# %%
class EnumExt(EnumBase):
    ONE = 1

# %%
class EnumBase1(enum.Enum):
    ONE = 1

# %%
class EnumExt1(EnumBase1):
    TWO = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 class EnumExt1(EnumBase1):
#       2     TWO = 2
#
# File /usr/lib/python3.12/enum.py:516, in EnumType.__prepare__(metacls, cls, bases, **kwds)
#     513 @classmethod
#     514 def __prepare__(metacls, cls, bases, **kwds):
#     515     # check that previous enum members do not exist
# --> 516     metacls._check_for_existing_members_(cls, bases)
#     517     # create the namespace dict
#     518     enum_dict = _EnumDict()
#
# File /usr/lib/python3.12/enum.py:962, in EnumType._check_for_existing_members_(mcls, class_name, bases)
#     960 for base in chain.__mro__:
#     961     if isinstance(base, EnumType) and base._member_names_:
# --> 962         raise TypeError(
#     963                 "<enum %r> cannot extend %r"
#     964                 % (class_name, base)
#     965                 )
#
# TypeError: <enum 'EnumExt1'> cannot extend <enum 'EnumBase1'>

# %%
Status.PENDING, Status['PENDING']
# Out:
# (<Status.PENDING: 'pending'>, <Status.PENDING: 'pending'>)

# %%
class Person:
    name = 'Alex'
    age = 100

# %%
Person.name
# Out:
# 'Alex'

# %%
getattr(Person, 'name')
# Out:
# 'Alex'

# %%
payload = """
{
    "name": "Alex",
    "status": "PENDING"
}
"""

# %%
import json
data = json.loads(payload)

# %%
data
# Out:
# {'name': 'Alex', 'status': 'PENDING'}

# %%
Status[data['status']]
# Out:
# <Status.PENDING: 'pending'>

# %%
def is_member(en, name):
    try:
        en[name]
    except KeyError:
        return False
    return True

# %%
is_member(Status, 'PENDING')
# Out:
# True

# %%
is_member(Status, 'OK')
# Out:
# False

# %%
getattr(Status, 'PENDING')
# Out:
# <Status.PENDING: 'pending'>

# %%
def is_member(en, name):
    return getattr(en, name, None) is not None

# %%
is_member(Status, 'PENDING')
# Out:
# True

# %%
is_member(Status, 'OK')
# Out:
# False

# %%
Status.__members__
# Out:
# mappingproxy({'PENDING': <Status.PENDING: 'pending'>,
#               'RUNNING': <Status.RUNNING: 'running'>,
#               'COMPLETED': <Status.COMPLETED: 'completed'>})

# %%
Status.__members__['PENDING']
# Out:
# <Status.PENDING: 'pending'>

# %%
'PENDING' in Status.__members__
# Out:
# True

# %%
'OK' in Status.__members__
# Out:
# False
