# %%
def fizz_buzz_3():
    for i in range(1, 100):
        if i % 15 == 0:
            # print('fizzbuzz')
            pass

        elif i % 3 == 0:
            # print('buzz')
            pass

        elif i % 5 == 0:
            # print('fizz')
            pass
        else:
            # print(i)
            pass

# %%
def fizz_buzz_5():
    for i in range(1, 100):
        if i % 15 == 0:
            # print('fizzbuzz')
            pass

        elif i % 5 == 0:
            # print('buzz')
            pass

        elif i % 3 == 0:
            # print('fizz')
            pass
        else:
            # print(i)
            pass

# %%
from timeit import timeit

# %%
help(timeit)
# Out:
# Help on function timeit in module timeit:
#
# timeit(stmt='pass', setup='pass', timer=<built-in function perf_counter>, number=1000000, globals=None)
#     Convenience function to create Timer object and call timeit method.

# %%
timeit('fizz_buzz_3()', globals=globals(), number=1_000_000)
# Out:
# 9.330226575000097

# %%
timeit('fizz_buzz_5()', globals=globals(), number=1_000_000)
# Out:
# 9.91138649000004
